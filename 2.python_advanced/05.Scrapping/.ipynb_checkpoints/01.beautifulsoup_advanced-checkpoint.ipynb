# %% [markdown]
# ### Targeted information retrieval

# %% [markdown]
# We have seen how to parse a webpage, which retrieves the information without distinction.
#
# But, in general, the purpose of scrapping is to automate the collection of targeted information on the web

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# Let's say I want to scrape the description of the latest movies released in theaters
#
# So I go to the allociné website and try to find the tags that will give me links to the specific pages of these movies to get their summaries.

# %% [markdown]
# #### Recovery of the url of the pages of films newly released in the theaters

# %%
url='http://www.allocine.fr/'
r = requests.get(url)
print(url, r.status_code)
soup = BeautifulSoup(r.content,'lxml')
soup
# Out:
# http://www.allocine.fr/ 200
# <!DOCTYPE html>
# <html lang="fr">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="index,follow,max-snippet:-1" name="robots"/>
# <title>AlloCiné : Cinéma, Séries TV, BO de films et séries, Vidéos, DVD et VOD</title>
# <meta content="" name="keywords"/>
# <meta content="noarchive" name="Googlebot"/>
# <meta content="global" name="distribution"/>
# <meta content="AlloCine" name="author"/>
# <meta content="France" name="country"/>
# <meta content="48.87078;2.30447" name="geo.position"/>
# <meta content="FR" name="geo.country"/>
# <meta content="48.87078;2.30447" name="ICBM"/>
# <meta content="#FECC00" name="theme-color"/>
# <meta content="AlloCiné, le site de référence du cinéma et des séries tv ! Découvrez notre recherche d'horaires de films, le programme tv de vos séries préférées, l'actualité ciné et séries, les émissions AlloCiné, les dernières bandes-annonces, et plus encore." name="description"/>
# <meta content="AlloCiné" property="og:site_name"/>
# <meta content="AlloCiné : Cinéma, Séries TV, BO de films et séries, Vidéos, DVD et VOD" property="og:title"/>
# <meta content="AlloCiné, le site de référence du cinéma et des séries tv ! Découvrez notre recherche d'horaires de films, le programme tv de vos séries préférées, l'actualité ciné et séries, les émissions AlloCiné, les dernières bandes-annonces, et plus encore." property="og:description"/>
# <meta content="99197768694" property="fb:app_id"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@allocine" name="twitter:site"/>
# <meta content="AlloCiné : Cinéma, Séries TV, BO de films et séries, Vidéos, DVD et VOD" name="twitter:title"/>
# <meta content="AlloCiné, le site de référence du cinéma et des séries tv ! Découvrez notre recherche d'horaires de films, le programme tv de vos séries préférées, l'actualité ciné et séries, les émissions AlloCiné, les dernières bandes-annonces, et plus encore." name="twitter:description"/>
# <meta content="" name="twitter:image"/>
# <meta content="allocine" name="twitter:app:name:iphone"/>
# <meta content="allocine" name="twitter:app:name:ipad"/>
# <meta content="allocine" name="twitter:app:name:googleplay"/>
# <meta content="allocine://open/" name="twitter:app:url:iphone"/>
# <meta content="allocine://open/" name="twitter:app:url:ipad"/>
# <meta content="allocine://open/" name="twitter:app:url:googleplay"/>
# <meta content="351184863" name="twitter:app:id:iphone"/>
# <meta content="351184863" name="twitter:app:id:ipad"/>
# <meta content="com.allocine.androidapp" name="twitter:app:id:googleplay"/>
# <meta content="app-id=351184863, app-argument=allocine://open/" name="apple-itunes-app"/>
# <meta content="107276450147" property="fb:pages"/>
# <link href="https://assets.allocine.fr" rel="preconnect"/>
# <link as="font" crossorigin="" href="https://assets.allocine.fr/skin/font/icon/font-icon-fec771a6e4.woff2" rel="preload" type="font/woff2"/>
# <link as="image" href="https://assets.allocine.fr/skin/img/allocine/logo-main-grey-32f06844b4.svg" rel="preload" type="image/svg+xml"/>
# <link as="script" href="https://assets.allocine.fr/js/website/website-common.f0d2a680761eb6e8289d.js" rel="preload"/>
# <link as="script" href="https://assets.allocine.fr/js/website/home.043e21d89a726ca76dc1.js" rel="preload"/>
# <link as="image" href="https://fr.web.img3.acsta.net/img/58/00/58000f2f3c4c56e98e42cde1a59f1bac.jpg" rel="preload"/>
# <style>article,aside,details,figcaption,figure,footer,header,hgroup,nav,section,summary{display:block}audio,canvas,video{display:inline-block}audio:not([controls]){display:none;height:0}[hidden],template{display:none}html{background:#fff;color:#000;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%}button,html,input,select,textarea{font-family:sans-serif}body{margin:0}a{background:transparent}a:focus{outline:thin dotted}a:active,a:hover{outline:0}abbr[title]{border-bottom:1px dotted}b,strong{font-weight:700}dfn{font-style:italic}mark{background:#ff0;color:#000}code,kbd,pre,samp{font-family:monospace,serif;font-size:1em}pre{white-space:pre;white-space:pre-wrap;word-wrap:break-word}q{quotes:"\201C" "\201D" "\2018" "\2019"}q:after,q:before{content:"";content:none}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sup{top:-.5em}sub{bottom:-.25em}img{border:0}svg:not(:root){overflow:hidden}figure{margin:0}fieldset{border:1px solid #ececec;margin:0 2px;padding:.35em .625em .75em}legend{border:0;padding:0;white-space:normal}button,input,select,textarea{font-family:inherit;font-size:100%;margin:0;vertical-align:baseline}button,input{line-height:normal}button,select{text-transform:none}button,html input[type=button],input[type=reset],input[type=submit]{-webkit-appearance:button;cursor:pointer}button[disabled],input[disabled]{cursor:default}input[type=checkbox],input[type=radio]{box-sizing:border-box;padding:0}input[type=search]{-webkit-appearance:textfield;box-sizing:content-box}input[type=search]::-webkit-search-cancel-button,input[type=search]::-webkit-search-decoration{-webkit-appearance:none}button::-moz-focus-inner,input::-moz-focus-inner{border:0;padding:0}textarea{overflow:auto;vertical-align:top}table{border-collapse:collapse;border-spacing:0}em{font-style:normal}*,:after,:before{box-sizing:border-box}::-moz-selection{background:#b3d4fc;text-shadow:none}::selection{background:#b3d4fc;text-shadow:none}input:focus{outline:none}p{margin:0}h1,h2,h3,h4,h5,h6{margin:0;padding:0;font-size:1em}hr{display:block;height:1px;border:0;margin:1em 0;padding:0}audio,canvas,img,video{vertical-align:middle}fieldset,textarea{border:0;margin:0;padding:0}textarea{resize:vertical;outline:0;font-size:13px;width:100%}li,ol,ul{list-style:none;margin:0;padding:0}address{font-style:normal}iframe{border:0}.alert:before,.dropdown-custom .btn,.icon:after,.icon:before,.more-trigger:after{font-family:font-icon;font-style:normal;font-weight:400;font-variant:normal;text-transform:none;speak:none;display:inline-block;vertical-align:middle;margin:0 .375rem;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.icon:after{margin-right:0}.icon:before{margin-left:0}.icon{font-size:1rem}.no-icon{display:none}.icon-centered:after,.icon-centered:before{margin:auto}@font-face{font-family:font-icon;src:url(https://assets.allocine.fr/skin/font/icon/font-icon-fec771a6e4.woff2) format("woff2"),url(https://assets.allocine.fr/skin/font/icon/font-icon-87118fa3de.woff) format("woff"),url(https://assets.allocine.fr/skin/font/icon/font-icon-8c2879c3a6.ttf) format("truetype");font-weight:400;font-style:normal}.footer-logo-WB{background-position:-284px 0;width:112px;height:29px}.footer-logo-boxoffice{background-position:-925px 0;width:315px;height:26px}.footer-logo{background-position:-398px 0;width:120px;height:34px}.header-arrow--bottom--black{background-position:0 0;width:16px;height:16px}.header-back{background-position:-92px 0;width:46px;height:46px}.header-burger{background-position:-140px 0;width:46px;height:46px}.header-home{background-position:-18px 0;width:16px;height:16px}.header-logo--primary{background-position:-661px 0;width:262px;height:74px}.header-logo-userspace{background-position:-520px 0;width:139px;height:39px}.header-minify{background-position:-188px 0;width:46px;height:46px}.header-music{background-position:-36px 0;width:16px;height:16px}.header-netflix{background-position:-54px  ...
# <script type="text/javascript">
# !function(a){var c="rcblock",e="rc-ko",t=localStorage.getItem(c);t===e&&(document.getElementsByTagName("html")[0].classList.add("m-ac-g-a"),a.RCBLOCK=!0)}(window);
# </script>
# <script type="text/javascript">
# (function(global) {
#     var fontStyleKey      = 'font_css_code';
#     var fontCssUrlKey     = 'font_css_url';
#     var brand             = 'allocine';
#     var fontCss           = localStorage.getItem(fontStyleKey);
#     var distantFontHash   = localStorage.getItem(fontCssUrlKey);
#     var currentFontHash   = 'https\u003A\/\/assets.allocine.fr\/skin\/css\/allocine\/font.min\u002Dc4d149dbf5.css';
#
#     if (fontCss && distantFontHash && (distantFontHash === currentFontHash)) {
#         var style           = document.createElement('style');
#             style.type      = 'text/css';
#             style.innerHTML = fontCss;
#
#       document.head.appendChild(style);
#
#       global.AC_FONT_LOADED = true;
#     }
# }(window));
# </script>
# <link href="https://assets.allocine.fr/favicon/allocine.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://assets.allocine.fr/favicon/allocine.ico" rel="icon" type="image/ico"/>
# <link href="https://assets.allocine.fr/apple-touch-icon/allocine.png" rel="apple-touch-icon"/>
# <link href="https://twitter.com/allocine" rel="me"/>
# </head>
# <body class="allocine allocine__homepage logged-out" id="allocine__homepage">
# <div class="sub-body">
# <div class="js-interstitial ad-interstitial ad-item" id="dfp-interstitial"></div>
# <header class="header-main" id="header-main">
# <div class="header-main-center">
# <div class="header-main-top">
# <div aria-label="Bouton Menu mobile" class="header-main-btn-mobile icon icon-hamburger" id="header-main-mobile-btn-menu"></div>
# <div class="header-main-logo-holder">
# <span class="ACrLw=ACr= header-main-logo">
# <img alt="allocine" class="header-main-logo-img" height="37" src="https://assets.allocine.fr/skin/img/allocine/logo-main-12195cd9d9.svg" width="162"/>
# <span class="header-main-logo-name">AlloCiné</span>
# </span>
# </div>
# <form action="/rechercher/" class="header-main-search" id="search-header" method="get">
# <fieldset class="header-main-search-fieldset" id="search-engine">
# <div class="header-search-form-container"><input class="header-search-input" id="header-search-input" name="q" placeholder="Rechercher un film, une série, une star..." type="text"/><button aria-label="Envoyer" class="header-search-submit icon icon-search" title="Rechercher" type="submit"></button></div> </fieldset>
# <p class="header-search-extralinks">
#                         Ex. :
#                         <a href="/film/fichefilm_gen_cfilm=242600.html">Un homme en colère</a>, <a href="/film/fichefilm_gen_cfilm=227548.html">West Side Story</a>, <a href="/series/ficheserie_gen_cserie=18145.html">Lucifer</a>, <a href="/series/ficheserie_gen_cserie=19475.html">The Resident</a> </p>
# <div class="header-main-search-mobile-layer" id="header-main-search-mobile-layer"></div>
# </form>
# <div class="header-ads-zone">
# <div class="js-headerlink ad-headerlink ad-item" id="dfp-headerlink"></div>
# </div>
# <div aria-label="Bouton Rechercher" class="header-main-btn-mobile icon icon-search" id="header-main-mobile-btn-search"></div>
# <span aria-label="Bouton Notez des films" class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIvc3BlZWRub3Rlci9jdWx0LW1vdmllcy8= button button-default-full button-sm icon icon-star-empty button-permanent-speednoter" data-ga='{"eventCategory":"my_brand","eventAction":"header_button","eventLabel":"entities_list"}' data-ga-trigger="clic">
# <span class="button-permanent-speednoter-text">Notez des films</span>
# </span>
# <div class="header-main-btn-mobile header-main-mobile-btn-userspace" id="header-main-mobile-btn-userspace">
# <span aria-label="Bouton Mon AlloCiné" class="icon icon-profil"></span>
# <img alt="" class="avatar js-myaccount-avatar" src="..."/>
# </div>
# </div>
# <div class="header-main-bottom">
# <nav class="header-main-nav" id="header-main-nav"><ul class="header-nav-holder"><li class="header-nav-item"><a class="header-nav-link" href="/film/" title="Cinéma">
#             Cinéma
#         </a></li><li class="header-nav-item"><a class="header-nav-link" href="/series/" title="Séries">
#             Séries
#         </a></li><li class="header-nav-item"><span class="ACrL3NACr0cmVhbWluZy8= header-nav-link" data-ga='{"hitType":"event","eventCategory":"op-svod","eventLabel":"https:\/\/www.allocine.fr\/","eventAction":"navigation_menu_click"}' data-ga-trigger="clic" title="Streaming">
#             Streaming
#         </span></li><li class="header-nav-item"><span class="ACrL25ACrld3Mv header-nav-link" title="News">
#             News
#         </span></li><li class="header-nav-item"><a class="header-nav-link" href="/trailer/" title="Trailers">
#             Trailers
#         </a></li><li class="header-nav-item"><a class="header-nav-link" href="/dvd/" title="DVD">
#             DVD
#         </a></li><li class="header-nav-item"><a class="header-nav-link" href="/vod/" title="VOD">
#             VOD
#         </a></li><li class="header-nav-item"><a class="header-nav-link" data-ga='{"hitType":"event","eventCategory":"op-kids","eventLabel":"https:\/\/www.allocine.fr\/","eventAction":"navigation_menu_click"}' data-ga-trigger="clic" href="/kids/" title="Kids">
#                         Kids
#                     </a></li><li class="header-nav-item"><span class="ACrL2RACrpc25leS8= header-nav-link-disney header-nav-link" data-ga='{"hitType":"event","eventCategory":"op-disneyplus","eventLabel":"https:\/\/www.allocine.fr\/","eventAction":"navigation_menu_click","dimension81":"2021-04-15"}' data-ga-trigger="clic" title="Disney+"><i class="header-nav-logo-disney"></i>DISNEY<span class="disney-plus">+</span></span></li></ul><h1 class="header-main-subnav-holder"><div class="header-main-ephemeride">Découvrez notre recherche de <a href="/salle/">séances cinéma</a>, les <a href="/news/">news</a> et <a href="/dossiers/">dossiers</a> cinéma et séries TV, les <a href="/video/">émissions AlloCiné</a>, les <a href="/video/bandes-annonces/plus-recentes/">dernières bandes-annonces</a> et plus encore...</div></h1></nav><div class="header-userspace-nav" id="header-userspace-nav"><span aria-label="Bouton Mon AlloCiné" class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIv header-nav-userspace-upper-link"><span class="icon icon-profil"></span><img alt="" class="avatar js-myaccount-avatar" src="..."/>
#                     Mon AlloCiné
#                 </span><div class="header-nav-userspace-holder"><div class="header-nav-userspace-sso"><span class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIvY29ubmV4aW9uLz9yZXR1cm5Vcmw9aHR0cHMlM0ElMkYlMkZ3d3cuYWxsb2NpbmUuZnIlMkY= button button-social-ac-ghost button-sm sign-in"><span class="txt">Identifiez-vous</span></span><span class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIvaW5zY3JpcHRpb24vP3JldHVyblVybD0lMkYlMkZtb24uYWxsb2NpbmUuZnIlMkY= button button-social-ac-full button-sm sign-up"><span class="txt">Créez votre compte</span></span></div><ul class="header-nav-userspace-subcontent"></ul></div></div> </div>
# </div>
# </header>
# <div class="main-banner">
# <div class="js-masthead ad-masthead ad-item" id="dfp-masthead"></div>
# </div>
# <main class="content-layout homepage-layout cf" id="content-layout">
# <div class="carousel carousel-main js-carousel" data-auto="true"><div class="carousel-row carousel-main-row"><figure class="carousel-item carousel-main-item current" data-index="1"><span class="ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvYXJ0aWNsZS9maWNoZWFydGljbGVfZ2VuX2NhcnRpY2xlPTE4Njk4NjA0Lmh0bWw= carousel-main-img-holder" data-ga='{"hitType":"event","eventAction":"homepage","eventCategory":"Carousel","eventLabel":"article\/fichearticle_gen_carticle=18698604.html","dimension34":null,"dimension35":null,"dimension36":null,"dimension37":null,"dimension39":null,"dimension41":"yes","dimension42":false,"dimension58":"Faites chauffer les moteurs !","dimension59":"editorial_content"}' data-ga-trigger="clic"><img class="carousel-main-image" height="400" src="https://fr.web.img3.acsta.net/img/58/00/58000f2f3c4c56e98e42cde1a59f1bac.jpg" title="Faites chauffer les moteurs !" width="1024"/></span><figcaption class="carousel-main-content"><span class="ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvYXJ0aWNsZS9maWNoZWFydGljbGVfZ2VuX2NhcnRpY2xlPTE4Njk4NjA0Lmh0bWw= title" data-ga='{"hitType":"event","eventAction":"homepage","eventCategory":"Carousel","eventLabel":"article\/fichearticle_gen_carticle=18698604.html","dimension34":null,"dimension35":null,"dimension36":null,"dimension37":null,"dimension39":null,"dimension41":"yes","dimension42":false,"dimension58":"Faites chauffer les moteurs !","dimension59":"editorial_content"}' data-ga-trigger="clic" title="Faites chauffer les moteurs !">Faites chauffer les moteurs !</span><div class="desc">Découvrez la nouvelle bande-annonce de "Fast &amp; Furious 9" ! Au cinéma le 14 juillet.</div></figcaption></figure><figure class="carousel-item carousel-main-item" data-index="2"><span class="ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvYXJ0aWNsZS9maWNoZWFydGljbGVfZ2VuX2NhcnRpY2xlPTE4Njk4NjU0Lmh0bWw= carousel-main-img-holder" data-ga='{"hitType":"event","eventAction":"homepage","eventCategory":"Carousel","eventLabel":"article\/fichearticle_gen_carticle=18698654.html","dimension34":null,"dimension35":null,"dimension36":null,"dimension37":null,"dimension39":null,"dimension41":"yes","dimension42":false,"dimension58":"Bruce Willis : on a rencontr\u00e9 sa nouvelle voix","dimension59":"editorial_content"}' data-ga-trigger="clic"><img class="carousel-main-image" data-src="https://fr.web.img6.acsta.net/img/4a/e2/4ae2919c4f0c885a3d073976280f86f4.jpg" height="400" src="..." title="Bruce Willis : on a rencontré sa nouvelle voix" width="1024"/></span><figcaption class="carousel-main-content"><span class="ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvYXJ0aWNsZS9maWNoZWFydGljbGVfZ2VuX2NhcnRpY2xlPTE4Njk4NjU0Lmh0bWw= title" data-ga='{"hitType":"event","eventAction":"homepage","eventCategory":"Carousel","eventLabel":"article\/fichearticle_gen_carticle=18698654.html","dimension34":null,"dimension35":null,"dimension36":null,"dimension37":null,"dimension39":null,"dimension41":"yes","dimension42":false,"dimension58":"Bruce Willis : on a rencontr\u00e9 sa nouvelle voix","dimension59":"editorial_content"}' data-ga-trigger="clic" title="Bruce Willis : on a rencontré sa nouvelle voix">Bruce Willis : on a rencontré sa nouvelle voix</span><div class="desc">Stefan Godin remplace le regretté Patrick Poivey dans "Cosmic Sin", à voir sur Prime Video.</div></figcaption></figure><figure class="carousel-item carousel-main-item" data-index="3"><span class="ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvYXJ0aWNsZS9maWNoZWFydGljbGVfZ2VuX2NhcnRpY2xlPTE4Njk4NDQ5Lmh0bWw= carousel-main-img-holder" data-ga='{"hitType":"event","eventAction":"homepage","eventCategory":"Carousel","eventLabel":"article\/fichearticle_gen_carticle=18698449.html","dimension34":null,"dimension35":null,"dimension36":null,"dimension37":null,"dimension39":null,"dimension41":"yes","dimension42":false,"dimension58":"Anim\u00e9s - Notre s\u00e9lection hebdo","dimension59":"editorial_content"}' data-ga-trigger="clic"><img class="carousel-main-image" data-src="https://fr.web.img3.acsta.net/img/7d/2b/7d2b5e4f3c291e2d ...
# <section class="section section-wrap">
# <div class="titlebar titlebar-top-border titlebar-page titlebar-page"><h2 class="titlebar-title titlebar-title-lg"><span class="ACrL2ZACrpbG0v titlebar-link">Cinéma</span></h2></div>
# <nav class="third-nav third-nav-hash js-third-nav">
# <a class="item" href="/film/meilleurs/">Meilleurs films</a> <a class="item js-item-mq-medium" href="/film/enfants/meilleurs/">Meilleurs films pour enfants</a> <a class="item" href="/film/meilleurs/documentaires/">Meilleurs documentaires</a> <a class="item" href="/films/">Tous les films</a>
# <div class="item-more js-third-sub-nav-holder">
# <span aria-label="Afficher plus d'éléments" class="item-more-picto icon icon-plus js-trigger-third-nav-sub"></span>
# <div class="third-nav-sub js-third-nav-sub">
# <a class="item" href="/film/meilleurs/decennie-2010/annee-2019/">Meilleurs films 2019</a> <a class="item" href="/film/enfants/">Tous les films pour enfants</a> <a class="item" href="/film/avantpremieres/">Avant-premières</a> <a class="item" href="/film/agenda/">Agenda des sorties</a> <a class="item" href="/film/enfants/aucinema/">Films pour enfants à l'affiche</a> <a class="item" href="/boxoffice/france/">Box Office</a> <span class="ACrL2ZACrlc3RpdmFscy8= item">Festivals</span> <span class="ACrL2ZACrpbG0vY291cnQtbWV0cmFnZS8= item">Court-métrages</span>
# </div>
# </div>
# </nav>
# <div class="search-theater cf js-search-theater-push" data-placeholder="Rechercher une salle : Nice, Bastille, 75001, UGC Lyon ..." data-route='{"locationRoute":{"name":"theaters_localization","objectParameters":{"localization":"id"}},"theaterRoute":{"name":"theater_showtimes","objectParameters":{"idTheater":"internalId"}},"searchRoute":{"name":"theaters_result_search","defaultParameters":null}}' role="search">
# <div class="js-search-location" data-placeholder="Rechercher une salle : Nice, Bastille, 75001, UGC Lyon ..." data-route='{"locationRoute":{"name":"theaters_localization","objectParameters":{"localization":"id"}},"theaterRoute":{"name":"theater_showtimes","objectParameters":{"idTheater":"internalId"}},"searchRoute":{"name":"theaters_result_search","defaultParameters":null}}' role="search">
# <form action="/salle/recherche/" autocomplete="off" class="form-holder theaters-form form form-localization" method="get">
# <fieldset class="form-field">
# <input class="form-text" id="q" name="q" placeholder="Rechercher une salle : Nice, Bastille, 75001, UGC Lyon ..." required="required" type="text"/>
# <button aria-label="Rechercher une salle : Nice, Bastille, 75001, UGC Lyon ..." class="form-submit button button-md icon icon-search" title="Rechercher une salle : Nice, Bastille, 75001, UGC Lyon ..." type="submit"></button>
# </fieldset>
# </form>
# </div>
# </div>
# </section>
# <section class="section-wrap">
# <div class="alert alert-warning mdl">
# <div class="alert-content">
# <span>Amis cinéphiles, le Covid-19 oblige les cinémas français à fermer leurs portes à nouveau. AlloCiné reste mobilisé pour vous accompagner tout au long du confinement, et apporte son soutien à tous les professionnels du cinéma.</span>
# </div>
# </div>
# </section>
# <div class="section section-wrap">
# <div class="gd gd-gap-20 gd-xs-12">
# <div class="gd-span-s-12 gd-span-l-1-8 gd-item-mw-0">
# <div class="titlebar"><h3 class="titlebar-title titlebar-title-md"><a class="titlebar-link" href="/video/bandes-annonces/">Bandes-annonces à ne pas manquer</a></h3></div>
# <div class="video-card-player info-hidden-on-play">
# <figure class="player js-player" data-model='{"context":"homepage","endScreen":true,"disableAutoPause":true,"launch":"play","disablePreroll":false,"disablePostroll":false,"videos":[{"id":19591895,"sources":{"medium":"\/\/fr.vid.web.acsta.net\/nmedia\/33\/21\/04\/13\/17\/19591895_sd_013.mp4","high":"\/\/fr.vid.web.acsta.net\/nmedia\/33\/21\/04\/13\/17\/19591895_hd_013.mp4"},"image":"\/videothumbnails\/21\/04\/13\/17\/28\/5463434.jpg","title":"Army of the Dead Bande-annonce VF","trackingIdentifier":"19591895-army_of_the_dead_bande_annonce_vf","embedUrl":"ACraHRACr0cHM6Ly9wbGF5ZXIuYWxsb2NpbmUuZnIvMTk1OTE4OTUuaHRtbA==","id_type":31003,"file_type":"trailer","description":"Army of the Dead Bande-annonce VF","duration":180,"view_count":8614,"added_at":{"date":"2021-04-13 17:27:00.000000","timezone_type":3,"timezone":"Europe\/Paris"},"metas":{"genre_main_movie":[{"name":"Action","id":"13025"},{"name":"Epouvante-horreur","id":"13009"}],"id_main_movie":271355,"image_main_movie":"\/pictures\/21\/04\/13\/10\/19\/0212496.jpg","localized_file_type":"trailer","main_movie_type":4002,"name_main_movie":"Army Of The Dead","trans_file_type":"Bande-annonce"},"relatedEntityDistributor":null,"relatedEntityDistributorId":null,"relatedEntityType":"movie","relatedEntityTrackingIdentifier":"271355-army_of_the_dead","relatedEntityTitle":"Army Of The Dead","relatedEntityId":271355,"genres":[{"id":"13025","name":"Action"},{"id":"13009","name":"Epouvante-horreur"}],"relatedEntityUrl":"ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvZmlsbS9maWNoZWZpbG1fZ2VuX2NmaWxtPTI3MTM1NS5odG1s","mediaUrl":"ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvdmlkZW8vcGxheWVyX2dlbl9jbWVkaWE9MTk1OTE4OTUmY2ZpbG09MjcxMzU1Lmh0bWw="}]}' data-thumb="https://fr.web.img3.acsta.net/r_640_360/videothumbnails/21/04/13/17/28/5463434.jpg">
# <div class="media-holder js-media-holder">
# <img alt="Army of the Dead Bande-annonce VF" class="media-cover js-media-cover" data-src="https://fr.web.img3.acsta.net/r_640_360/videothumbnails/21/04/13/17/28/5463434.jpg" height="360" src="..." width="640"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# <script type="text/javascript">
#     var wads = wads || {};
#     var wadsBeforeStartAlreadyDone = false;
#     var wadsQuery = 'route=homepage';
#
#     function wadsBeforeStart() {
#         if (wadsBeforeStartAlreadyDone) {
#             return false;
#         }
#
#         wads.mode = 'async';
#         wads.public.setSitePage('allocine_fr/home');
#
#         // update sitepage only for mobile & tablet
#         if (window.innerWidth < 480) {
#             wads.public.setSitePage(wads.sitepage.replace('/', '_mobile/'));
#         } else if(
#             window.innerWidth < 992 ||
#             /Android|webOS|iPhone|iPad|iPod|BlackBerry|IEMobile|Opera Mini/i.test(navigator.userAgent)
#         ) {
#             wads.public.setSitePage(wads.sitepage.replace('/', '_tablet/'));
#         }
#
#         wads.callBaseUrlAutopromo = 'http://autopromo.allocine.fr';
#         wads.cookieBaseUrlAutopromo = 'http://autopromo.allocine.fr';
#         wads.callBaseUrlAcceptable = 'http://acceptable.allocine.fr';
#         wads.cookieBaseUrlAcceptable = 'http://acceptable.allocine.fr';
#
#         wadsBeforeStartAlreadyDone = true;
#     }
# </script>
# <div class="media-player-holder">
# <div class="js-media-player"></div>
# </div>
# </div>
# </figure>
# <div class="player-info">
# <span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTkxODk1JmNmaWxtPTI3MTM1NS5odG1s item item-link img-holder">
# <img alt="Army Of The Dead" class="show-img" data-src="https://fr.web.img2.acsta.net/r_80_106/pictures/21/04/13/10/19/0212496.jpg" src="..."/>
# </span>
# <div class="item">
# <a class="item-link show-name" href="/film/fichefilm_gen_cfilm=271355.html">Army Of The Dead</a>
# <a class="item-link" href="/video/player_gen_cmedia=19591895&amp;cfilm=271355.html">Army of the Dead Bande-annonce VF</a>
# </div>
# </div>
# </div>
# <div class="gd gd-gap-15 gd-xs-2 gd-s-4 mdl-inside">
# <div class="card video-card-trailer">
# <figure class="thumbnail">
# <div class="thumbnail-layer">
# <div class="layer-link-holder"><a class="layer-link" href="/video/player_gen_cmedia=19587514&amp;cfilm=221542.html">Fast &amp; Furious 9 Bande-annonce VO</a></div>
# </div>
# <span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTg3NTE0JmNmaWxtPTIyMTU0Mi5odG1s thumbnail-container thumbnail-link" title="Fast &amp; Furious 9 Bande-annonce VO">
# <img alt="Fast &amp; Furious 9 Bande-annonce VO" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_150_200/pictures/21/04/15/09/57/4264688.jpg" height="200" src="..." width="150"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# <span class="thumbnail-count">3:23</span>
# </span>
# </figure>
# </div>
# <div class="card video-card-trailer">
# <figure class="thumbnail">
# <div class="thumbnail-layer">
# <div class="layer-link-holder"><a class="layer-link" href="/video/player_gen_cmedia=19584961&amp;cfilm=186636.html">Top Gun: Maverick Bande-annonce (2) VO</a></div>
# </div>
# <span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTg0OTYxJmNmaWxtPTE4NjYzNi5odG1s thumbnail-container thumbnail-link" title="Top Gun: Maverick Bande-annonce (2) VO">
# <img alt="Top Gun: Maverick Bande-annonce (2) VO" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_150_200/pictures/21/04/12/16/55/4194493.jpg" height="200" src="..." width="150"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# <span class="thumbnail-count">2:12</span>
# </span>
# </figure>
# </div>
# <div class="card video-card-trailer">
# <figure class="thumbnail">
# <div class="thumbnail-layer">
# <div class="layer-link-holder"><a class="layer-link" href="/video/player_gen_cmedia=19587800&amp;cfilm=264612.html">Hitman &amp; Bodyguard Bande-annonce VO</a></div>
# </div>
# <span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTg3ODAwJmNmaWxtPTI2NDYxMi5odG1s thumbnail-container thumbnail-link" title="Hitman &amp; Bodyguard Bande-annonce VO">
# <img alt="Hitman &amp; Bodyguard Bande-annonce VO" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_150_200/pictures/21/04/13/15/37/5615244.jpg" height="200" src="..." width="150"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# <span class="thumbnail-count">2:08</span>
# </span>
# </figure>
# </div>
# <div class="card video-card-trailer">
# <figure class="thumbnail">
# <div class="thumbnail-layer">
# <div class="layer-link-holder"><a class="layer-link" href="/video/player_gen_cmedia=19590890&amp;cfilm=271379.html">Shadow in the Cloud Teaser VO</a></div>
# </div>
# <span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTkwODkwJmNmaWxtPTI3MTM3OS5odG1s thumbnail-container thumbnail-link" title="Shadow in the Cloud Teaser VO">
# <img alt="Shadow in the Cloud Teaser VO" class="thumbnail-img" data-src="https://fr.web.img2.acsta.net/c_150_200/pictures/20/12/22/10/16/0936597.jpg" height="200" src="..." width="150"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# <span class="thumbnail-count">1:01</span>
# </span>
# </figure>
# </div>
# </div>
# </div>
# <div class="gd-span-s-12 gd-span-l-9-4">
# <div id="mobile-referrer-atf"></div>
# <div class="movie-next">
# <div class="titlebar"><h3 class="titlebar-title titlebar-title-md"><span class="ACrL2ZACrpbG0vYXR0ZW5kdXMv titlebar-link">Prochainement</span></h3><div class="light titlebar-subtile"><span class="titlebar-subtile-txt">Classement des films les plus consultés hier</span></div></div>
# <ul class="list-entity list-movie-hp small-crop mdl-fixed">
# <li class="list-entity-item list-entity-item-first cf">
# <figure class="thumbnail">
# <span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTg3NTE0JmNmaWxtPTIyMTU0Mi5odG1s thumbnail-container thumbnail-link" title="Fast &amp; Furious 9">
# <img alt="Fast &amp; Furious 9" class="thumbnail-img" data-src="https://fr.web.img2.acsta.net/c_120_160/pictures/21/04/15/09/57/4264688.jpg" height="160" src="..." width="120"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="list-entity-title-link" href="/film/fichefilm_gen_cfilm=221542.html"> Fast &amp; Furious 9 </a>
# </div>
# <div class="meta-body">
# <p class="genre"> Film - Action</p>
# </div>
# <span aria-label="Lire" class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTg3NTE0JmNmaWxtPTIyMTU0Mi5odG1s icon icon-play-mini"> </span>
# </div>
# </li>
# <li class="list-entity-item">
# <a class="list-entity-item-link" href="/film/fichefilm_gen_cfilm=271687.html"> Nomadland</a>
# <a aria-label="Lire" class="icon icon-play-mini" href="/video/player_gen_cmedia=19591089&amp;cfilm=271687.html"> </a>
# </li>
# <li class="list-entity-item">
# <a class="list-entity-item-link" href="/film/fichefilm_gen_cfilm=240935.html"> Godzilla vs Kong</a>
# <a aria-label="Lire" class="icon icon-play-mini" href="/video/player_gen_cmedia=19585574&amp;cfilm=240935.html"> </a>
# </li>
# <li class="list-entity-item">
# <a class="list-entity-item-link" href="/film/fichefilm_gen_cfilm=211938.html"> Space Jam - Nouvelle ère</a>
# <a aria-label="Lire" class="icon icon-play-mini" href="/video/player_gen_cmedia=19589556&amp;cfilm=211938.html"> </a>
# </li>
# <li class="list-entity-item">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yNDI2MDAuaHRtbA== list-entity-item-link"> Un homme en colère</span>
# <a aria-label="Lire" class="icon icon-play-mini" href="/video/player_gen_cmedia=19589615&amp;cfilm=242600.html"> </a>
# </li>
# <li class="more-trigger js-more-trigger">Voir plus de films</li>
# <li class="row more-hidden">
# <ul>
# <li class="list-entity-item">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yNjQ2MTIuaHRtbA== list-entity-item-link"> Hitman &amp; Bodyguard 2</span>
# <span aria-label="Lire" class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTg3ODAwJmNmaWxtPTI2NDYxMi5odG1s icon icon-play-mini"> </span>
# </li>
# <li class="list-entity-item">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yNTY4ODAuaHRtbA== list-entity-item-link"> Spider-Man: No Way Home</span>
# </li>
# <li class="list-entity-item">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0xODY2MzYuaHRtbA== list-entity-item-link"> Top Gun: Maverick</span>
# <span aria-label="Lire" class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTg0OTYxJmNmaWxtPTE4NjYzNi5odG1s icon icon-play-mini"> </span>
# </li>
# <li class="list-entity-item">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yMzA3ODMuaHRtbA== list-entity-item-link"> Black Widow</span>
# <span aria-label="Lire" class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTkxNzk4JmNmaWxtPTIzMDc4My5odG1s icon icon-play-mini"> </span>
# </li>
# <li class="list-entity-item">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yNDU1MzUuaHRtbA== list-entity-item-link"> The Suicide Squad</span>
# <span aria-label="Lire" class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTkwMjgyJmNmaWxtPTI0NTUzNS5odG1s icon icon-play-mini"> </span>
# </li>
# </ul>
# </li>
# </ul>
# <a class="end-section-link" href="/film/attendus/" title="Tous les films à venir">Tous les films à venir</a>
# </div>
# </div>
# </div>
# </div>
# <section class="section section-wrap">
# <div class="titlebar"><h3 class="titlebar-title titlebar-title-md"><a class="titlebar-link" href="/news/cinema/">Dernières news cinéma</a></h3></div>
# <div class="gd gd-gap-15 gd-xs-1 gd-m-3">
# <div class="card news-card news-card-col news-card news-card-list cf"><figure class="thumbnail"><div class="thumbnail-container"><img alt="Godzilla vs Kong privé de sortie cinéma" class="thumbnail-img" data-src="https://fr.web.img5.acsta.net/c_400_225/newsv7/21/04/15/15/40/0315841.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NEWS - Sorties ciné</div><div class="meta-date">jeudi 15 avril 2021</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=18698703.html">Godzilla vs Kong privé de sortie cinéma</a></div></div></div>
# <div class="card news-card news-card-col news-card news-card-list cf"><figure class="thumbnail no-thumb"><div class="thumbnail-container"><img alt="Le Chant du Loup sur M6 : François Civil et Omar Sy ont-ils tourné dans de vrais sous-marins ?" class="thumbnail-img" data-src="https://fr.web.img5.acsta.net/c_400_225/newsv7/21/04/13/16/31/0421202.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NEWS - Films à la TV</div><div class="meta-date">jeudi 15 avril 2021</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=18698211.html">Le Chant du Loup sur M6 : François Civil et Omar Sy ont-ils tourné dans de vrais sous-marins ?</a></div></div></div>
# <div class="card news-card news-card-col news-card news-card-list cf"><figure class="thumbnail no-thumb no-thumb"><div class="thumbnail-container"><img alt="Raya et le dernier dragon sera diffusé en exclusivité sur Disney+" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_400_225/newsv7/21/04/15/14/44/0077973.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NEWS - Films à la TV</div><div class="meta-date">jeudi 15 avril 2021</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=18698694.html">Raya et le dernier dragon sera diffusé en exclusivité sur Disney+</a></div></div></div>
# <div class="card news-card news-card-col news-card news-card-list cf"><figure class="thumbnail no-thumb no-thumb no-thumb"><div class="thumbnail-container"><img alt="Fermeture des salles : aller au cinéma manque à 63 % des Français" class="thumbnail-img" data-src="https://fr.web.img4.acsta.net/c_400_225/newsv7/21/04/15/10/56/4823644.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NEWS - Box Office</div><div class="meta-date">jeudi 15 avril 2021</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=18698679.html">Fermeture des salles : aller au cinéma manque à 63 % des Français</a></div></div></div>
# <div class="card news-card news-card-col news-card news-card-list cf"><figure class="thumbnail no-thumb no-thumb no-thumb no-thumb"><div class="thumbnail-container"><img alt="Scream : la méthode insolite des cinéastes pour éviter les spoilers" class="thumbnail-img" data-src="https://fr.web.img2.acsta.net/c_400_225/newsv7/21/04/15/11/47/4986544.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NEWS - Films à la TV</div><div class="meta-date">jeudi 15 avril 2021</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=18698338.html">Scream : la méthode insolite des cinéastes pour éviter les spoilers</a></div></div></div>
# <div class="card news-card news-card-col news-card news-card-list cf"><figure class="thumbnail no-thumb no-thumb no-thumb no-thumb no-thumb"><div class="thumbnail-container"><img alt="Fast &amp; Furious 9 : un crossover avec Jurassic Park ? Justin Lin est partant !" class="thumbnail-img" data-src="https://fr.web.img4.acsta.net/c_400_225/newsv7/21/04/14/15/12/2050136.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NEWS - Interviews</div><div class="meta-date">jeudi 15 avril 2021</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=18698656.html">Fast &amp; Furious 9 : un crossover avec Jurassic Park ? Justin Lin est partant !</a></div></div></div>
# <div class="card news-card news-card-col news-card news-card-list cf"><figure class="thumbnail no-thumb no-thumb no-thumb no-thumb no-thumb no-thumb"><div class="thumbnail-container"><img alt="A la TV jeudi 15 avril : tous les films et séries à voir ce soir" class="thumbnail-img" data-src="https://fr.web.img2.acsta.net/c_400_225/newsv7/21/04/05/15/19/0802565.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NEWS - Films à la TV</div><div class="meta-date">jeudi 15 avril 2021</div><div class="meta-title"><span class="ACrL2FACrydGljbGUvZmljaGVhcnRpY2xlX2dlbl9jYXJ0aWNsZT0xODY5ODM5MS5odG1s meta-title-link">A la TV jeudi 15 avril : tous les films et séries à voir ce soir</span></div></div></div>
# <div class="card news-card news-card-col news-card news-card-list cf"><figure class="thumbnail no-thumb no-thumb no-thumb no-thumb no-thumb no-thumb no-thumb"><div class="thumbnail-container"><img alt="Ride or Die sur Netflix : c'est quoi ce film japonais qui mêle thriller et romance lesbienne ?" class="thumbnail-img" data-src="https://fr.web.img3.acsta.net/c_400_225/newsv7/21/04/15/10/51/5915627.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NEWS - Films à la TV</div><div class="meta-date">jeudi 15 avril 2021</div><div class="meta-title"><span class="ACrL2FACrydGljbGUvZmljaGVhcnRpY2xlX2dlbl9jYXJ0aWNsZT0xODY5ODY4NS5odG1s meta-title-link">Ride or Die sur Netflix : c'est quoi ce film japonais qui mêle thriller et romance lesbienne ?</span></div></div></div>
# <div class="card news-card news-card-col news-card news-card-list cf"><figure class="thumbnail no-thumb no-thumb no-thumb no-thumb no-thumb no-thumb no-thumb no-thumb"><div class="thumbnail-container"><img alt="Star Wars : comment la saga a fait la fortune de Spielberg ?" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_400_225/newsv7/21/04/14/11/21/4616832.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NEWS - Culture ciné</div><div class="meta-date">jeudi 15 avril 2021</div><div class="meta-title"><span class="ACrL2FACrydGljbGUvZmljaGVhcnRpY2xlX2dlbl9jYXJ0aWNsZT0xODY5ODY0Mi5odG1s meta-title-link">Star Wars : comment la saga a fait la fortune de Spielberg ?</span></div></div></div> </div>
# <span class="ACrL25ACrld3MvY2luZW1hLw== end-section-link no-mg-bottom" title="Toutes les news cinéma">Toutes les news cinéma</span>
# <span class="hidden-xs">-
#
#
#
#
#
#             <a class="end-section-link no-mg-bottom" href="/dossiers/cinema/" title="Tous les dossiers cinéma">Tous les dossiers cinéma</a>
# </span>
# </section>
# <section class="section section-wrap">
# <div class="gd-2-cols gd-gap-30">
# <div class="gd-col-left">
# <div class="mdl-inside">
# <div id="newsletter-anchor-lc"></div>
# <span class="ACrL2ZACrpbG0vc29ydGllcy1zZW1haW5lLw== end-section-link" title="Toutes les sorties de la semaine">Toutes les sorties de la semaine</span>
# </div>
# <div class="mdl-outside">
# <div class="titlebar titlebar-arrow"><h3 class="titlebar-title titlebar-title-md"><span class="ACrL2ZACrpbG0vYXVjaW5lbWEv titlebar-link">Toujours à l'affiche</span></h3></div>
# <div class="emergency-visuel-wrapper">
# <span class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIvc3BlZWRub3Rlci9jYW1wYWlnbi8yMDY1MS8=">
# <img alt="Quels films avez vous le plus envie d'aller voir ?" class="emergency-visuel rwd-visuel emergency-visuel-desktop" data-src="https://fr.web.img5.acsta.net/commons/v9/allocine/emergency/visuel-emergency-bot-large.png" src="..."/>
# <img alt="Quels films avez vous le plus envie d'aller voir ?" class="emergency-visuel rwd-visuel emergency-visuel-tablette" data-src="https://fr.web.img3.acsta.net/commons/v9/allocine/emergency/visuel-emergency-bot-medium.png" src="..."/>
# <img alt="Quels films avez vous le plus envie d'aller voir ?" class="emergency-visuel rwd-visuel emergency-visuel-mobile" data-src="https://fr.web.img6.acsta.net/commons/v9/allocine/emergency/visuel-emergency-bot-small.png" src="..."/>
# </span>
# </div>
# <a class="end-section-link" href="/film/aucinema/" title="Tous les films encore à l'affiche">Tous les films encore à l'affiche</a>
# </div>
# </div>
# <div class="gd-col-right">
# <div class="js-atf ad-atf ad-item" id="dfp-atf"></div>
# </div>
# </div>
# </section>
# <section class="section section-wrap">
# <div class="titlebar titlebar-top-border titlebar-page titlebar-page"><h2 class="titlebar-title titlebar-title-lg">SVOD &amp; VOD</h2></div>
# </section>
# <section class="section section-wrap">
# <div class="menu-provider-text">Accédez au contenu du catalogue de votre plateforme préférée :</div>
# <div class="roller-holder js-roller roller-arrow-title roller-streaming-nav" data-offset="20"><div class="roller-overflow"><div class="roller-slider"><div class="roller-item"><div class="nav-item"><div class="nav-item-logo"><img alt="Disney+" src="https://fr.web.img4.acsta.net/f_png/r_60_60/commons/v9/common/svod_providers/square-disney.png"/></div><div class="nav-item-text"><a class="nav-item-link" href="/disney/">Disney+</a></div></div></div><div class="roller-item"><div class="nav-item"><div class="nav-item-logo"><img alt="Netflix" src="https://fr.web.img6.acsta.net/f_png/r_60_60/commons/v9/common/svod_providers/square-netflix.png"/></div><div class="nav-item-text"><a class="nav-item-link" href="/netflix/">Netflix</a></div></div></div><div class="roller-item"><div class="nav-item"><div class="nav-item-logo"><img alt="Amazon Prime Video" src="https://fr.web.img4.acsta.net/f_png/r_60_60/commons/v9/common/svod_providers/square-amazon.png"/></div><div class="nav-item-text"><a class="nav-item-link" href="/amazon/">Amazon Prime Video</a></div></div></div><div class="roller-item"><div class="nav-item"><div class="nav-item-logo"><img alt="Canal+" src="https://fr.web.img3.acsta.net/f_png/r_60_60/commons/v9/common/svod_providers/square-mycanal.png"/></div><div class="nav-item-text"><a class="nav-item-link" href="/mycanal/">Canal+</a></div></div></div><div class="roller-item"><div class="nav-item"><div class="nav-item-logo"><img alt="OCS" src="https://fr.web.img6.acsta.net/f_png/r_60_60/commons/v9/common/svod_providers/square-ocs.png"/></div><div class="nav-item-text"><a class="nav-item-link" href="/ocs/">OCS</a></div></div></div><div class="roller-item"><div class="nav-item"><div class="nav-item-logo"><img alt="Salto" src="https://fr.web.img6.acsta.net/f_png/r_60_60/commons/v9/common/svod_providers/square-salto.png"/></div><div class="nav-item-text"><span class="ACrL3NACrhbHRvLw== nav-item-link">Salto</span></div></div></div><div class="roller-item"><div class="nav-item"><div class="nav-item-logo"><img alt="Apple TV+" src="https://fr.web.img2.acsta.net/f_png/r_60_60/commons/v9/common/svod_providers/square-appletv.png"/></div><div class="nav-item-text"><span class="ACrL2FACrwcGxldHZwbHVzLw== nav-item-link">Apple TV+</span></div></div></div></div></div><div class="roller-btn-holder"><button aria-label="Bouton aller vers la gauche" class="roller-btn btn-left icon icon-arrow-left disabled"></button><button aria-label="Bouton aller vers la droite" class="roller-btn btn-right icon icon-arrow-right"></button></div></div> </section>
# <section class="gd-2-cols gd-gap-30 section section-wrap">
# <div class="gd-col-left">
# <div class="titlebar"><h3 class="titlebar-title titlebar-title-md">Bandes-Annonces streaming</h3></div>
# <div class="video-card-player info-hidden-on-play">
# <figure class="player js-player" data-model='{"context":"homepage","endScreen":true,"disableAutoPause":true,"launch":"play","disablePreroll":true,"disablePostroll":true,"videos":[{"id":19585573,"sources":{"standard":"https:\/\/fr.vid.web.acsta.net\/nmedia\/33\/21\/03\/17\/15\/19585573_sd_013.mp4"},"image":"\/videothumbnails\/21\/03\/17\/15\/05\/1752661.jpg","title":"Love And Monsters Bande-annonce VO","trackingIdentifier":"19585573-n_a","embedUrl":"ACraHRACr0cHM6Ly9wbGF5ZXIuYWxsb2NpbmUuZnIvMTk1ODU1NzMuaHRtbA==","file_type":"TRAILER","description":null,"duration":"00:02:20","view_count":75210,"added_at":null,"metas":{"id_main_show":null,"name_main_show":null,"image_main_show":null,"id_main_movie":209011,"name_main_movie":"Love And Monsters","image_main_movie":"\/pictures\/20\/10\/01\/10\/37\/5061463.jpg","id_main_series":null,"name_main_series":null,"image_main_series":null,"id_main_season":null,"name_main_season":null,"image_main_season":null,"main_season_number":null,"id_main_person":null,"name_main_person":null,"image_main_person":null,"use_portal":null,"release_date_main_movie":null,"nb_days_release_main_movie":null,"id_meta_category":null,"name_meta_category":null,"localized_file_type":null,"trans_file_type":null,"main_movie_type":null,"main_season_rating":null,"main_series_rating":null,"main_season_user_note_count":null,"genre_main_movie":null,"genre_main_series":null,"release_status_movie":null,"release_status_series":null},"relatedEntityType":"movie"}]}' data-thumb="https://fr.web.img4.acsta.net/r_640_360/videothumbnails/21/03/17/15/05/1752661.jpg">
# <div class="media-holder js-media-holder">
# <img alt="" class="media-cover js-media-cover" data-src="https://fr.web.img4.acsta.net/r_640_360/videothumbnails/21/03/17/15/05/1752661.jpg" height="360" src="..." width="640"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# <div class="media-player-holder">
# <div class="js-media-player"></div>
# </div>
# </div>
# </figure>
# <div class="player-info">
# <span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTg1NTczJmNmaWxtPTIwOTAxMS5odG1s item item-link img-holder">
# <img alt="Love And Monsters" class="show-img" data-src="https://fr.web.img2.acsta.net/r_80_106/pictures/20/10/01/10/37/5061463.jpg" src="..."/>
# </span>
# <div class="item">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yMDkwMTEuaHRtbA== item-link show-name">Love And Monsters</span>
# ...
# </div>
# <div class="brand-link">
# <span class="ACraHRACr0cHM6Ly93d3cuc2Vuc2FjaW5lLmNvbS8=">SensaCine</span> <span class="light">Espagne</span>
# </div>
# <div class="brand-link">
# <span class="ACraHRACr0cDovL3d3dy5iZXlhenBlcmRlLmNvbS8=">Beyazperde</span> <span class="light">Turquie</span>
# </div>
# <div class="brand-link">
# <span class="ACraHRACr0cHM6Ly93d3cuYWRvcm9jaW5lbWEuY29tLw==">AdoroCinema</span> <span class="light">Brésil</span>
# </div>
# <div class="brand-link">
# <span class="ACraHRACr0cHM6Ly93d3cuc2Vuc2FjaW5lLmNvbS5teC8=">Sensacine México</span> <span class="light">Mexique</span>
# </div>
# </div>
# </div>
# </div>
# <div class="main-footer-bottom">
# <p class="info">
# <span class="ACrL3NACrlcnZpY2UvY29udGFjdC8=">Contact</span> <span class="pipe">|</span>
# <span class="ACrL3NACrlcnZpY2UvYXByb3Bvcy8=">Qui sommes-nous</span> <span class="pipe">|</span>
# <span class="ACraHRACr0cDovL3d3dy53ZWJlZGlhLmZy" rel="noopener" target="_blank"> Recrutement</span> <span class="pipe">|</span>
# <span class="ACraHRACr0cDovL3NwZWNzLndlYmVkaWEuZnI=" rel="noopener" target="_blank">Publicité</span> <span class="pipe">|</span>
# <span class="ACrL3NACrlcnZpY2UvY29uZGl0aW9ucy5odG1s">CGU</span> <span class="pipe">|</span>
# <span class="ACrL3NACrlcnZpY2UvY29va2llcy5odG1s">Politique de cookies</span> <span class="pipe">|</span>
# <a class="cookie-notice" href="#">Préférences cookies</a> <span class="pipe">|</span>
# <span class="ACrL3NACrlcnZpY2UvY2hhcnRlLmh0bWw=">Données Personnelles</span> <span class="pipe">|</span>
# <span class="ACrL3NACrlcnZpY2Uvbm90ZS1wcmVzc2UuaHRtbA==">Revue de presse</span> <span class="pipe">|</span>
# <span class="ACrL3NACrlcnZpY2Uv">Les services AlloCiné</span> <span class="pipe">|</span>
#     ©AlloCiné
# </p>
# <p class="info">
#     Retrouvez tous les horaires et infos de votre cinéma sur le numéro AlloCiné : <span class="phone">0 892 892 892</span> (0,34€/minute)
# </p>
# <p class="info-logo">
# <i class="sp footer-logo"></i>
# <i class="sp footer-logo-boxoffice"></i>
# </p>
# </div>
# </footer>
# <div class="mq-state" id="mq-state"></div>
# <div class="message-board">
# <div class="js-message-board"></div>
# </div>
# <a aria-label="Retour en haut de la page" class="back-top icon icon-arrow-top" href="#allocine__homepage" id="back-top">
# <span class="no-icon">Back to Top</span>
# </a>
# <div class="easyAdsBox"> </div>
# <div id="modal-anchors-container">
# </div>
# <!-- DIDOMI GLOBALS -->
# <script type="text/javascript">
#     window.didomiOnReady = window.didomiOnReady || [];
#     window.didomiEventListeners = window.didomiEventListeners || [];
# </script>
# <!-- DIDOMI CMP SCRIPT WITH PAYWAL -->
# <script type="text/javascript">window.gdprAppliesGlobally=true;(function(){function a(e){if(!window.frames[e]){if(document.body&&document.body.firstChild){var t=document.body;var n=document.createElement("iframe");n.style.display="none";n.name=e;n.title=e;t.insertBefore(n,t.firstChild)}
#     else{setTimeout(function(){a(e)},5)}}}function e(n,r,o,c,s){function e(e,t,n,a){if(typeof n!=="function"){return}if(!window[r]){window[r]=[]}var i=false;if(s){i=s(e,t,n)}if(!i){window[r].push({command:e,parameter:t,callback:n,version:a})}}e.stub=true;function t(a){if(!window[n]||window[n].stub!==true){return}if(!a.data){return}
#     var i=typeof a.data==="string";var e;try{e=i?JSON.parse(a.data):a.data}catch(t){return}if(e[o]){var r=e[o];window[n](r.command,r.parameter,function(e,t){var n={};n[c]={returnValue:e,success:t,callId:r.callId};a.source.postMessage(i?JSON.stringify(n):n,"*")},r.version)}}
#     if(typeof window[n]!=="function"){window[n]=e;if(window.addEventListener){window.addEventListener("message",t,false)}else{window.attachEvent("onmessage",t)}}}e("__tcfapi","__tcfapiBuffer","__tcfapiCall","__tcfapiReturn");a("__tcfapiLocator");(function(e){
#     var t=document.createElement("script");t.id="spcloader";t.type="text/javascript";t.async=true;t.src="https://sdk.privacy-center.org/"+e+"/loader.js?target_type=notice&target=TtwHt2xD";t.charset="utf-8";var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(t,n)})('e23a01f6-a508-4e71-8f50-c1a9cae7c0d0')})();</script>
# <!-- DIDOMI CMP SCRIPT ENDS -->
# <script type="text/javascript">
#             var dataLayerGA = {"dimension10":"homepage"};
#         </script>
# <script type="text/javascript">
#         var JadConfig = {"provider":"dfp","system":"jad","account-id":"\/120157152","account-first-level":"\/ALLOCINE_FR_WEB","tag-id":"\/120157152\/ALLOCINE_FR_WEB","tag-other-levels":"\/homepage\/home","navEgg":null,"targeting":{"site":"allocine","site_route":"homepage","site_section":"home","environment":"web","video_id":"19591895","video_movie_id":"271355","video_movie_genre":["13025","13009"],"is_for_kids":"0"},"autoRefresh":true,"cmpPaywall":{"name":"didomi","siteId":"e23a01f6-a508-4e71-8f50-c1a9cae7c0d0","noticeId":"TtwHt2xD","paywall":{"clientId":"AVvF60FpOZcS6UoBe6sf8isBLYwzuLgMQCnNdE-FvpoW_OhR8P6zERqhyuIBGPOxqrTHKxv7QxsXnfck","planId":"P-66F73522PX986223DMBQZG5A","tosUrl":"\/service\/cgv.html","touUrl":"\/service\/conditions.html","privacyUrl":"\/service\/charte.html"},"includeCmp":false}};
#         var JadIds    = ["dfp-interstitial","dfp-headerlink","dfp-masthead","dfp-atf","dfp-pulse"];
#     </script>
# <script type="text/javascript">(function (win) {
#     win.AC = win.AC || {};
#     AC.config = {"releaseWeekDay":"Wednesday","locale":"fr_FR","lang":"fr","brand":"allocine","siteKey":"fr","graphCountryName":"FRANCE","display_provider":"jad","asset_version":"74fb277f66ad82743977326fcd462d143b110a75","env":"prod","assetsUrls":{"css":{"secondary":"https:\/\/assets.allocine.fr\/skin\/css\/allocine\/secondary-styles.min-e23f914690.css","font":"https:\/\/assets.allocine.fr\/skin\/css\/allocine\/font.min-c4d149dbf5.css"},"images":{"logo":"https:\/\/assets.allocine.fr\/skin\/img\/logo-allocine-287bbe0668.svg","bronson":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/bronson-e492ec8e56.gif","seriously":"https:\/\/assets.allocine.fr\/skin\/img\/seriously-ffccba6479.gif","walle":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/walle-5d973cbbc2.png","notFound":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/not-found-dec1f46fbc.gif","ghostBuster":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/ghostbuster-7c731e1347.png","etoile":"https:\/\/assets.allocine.fr\/skin\/img\/etoiles-766780d2bf.png","onboarding":"https:\/\/assets.allocine.fr\/skin\/img\/allocine\/onboarding-a32c4541a1.png","suggestions":"https:\/\/assets.allocine.fr\/skin\/img\/suggestions-0009180ea0.png","macaron":"https:\/\/assets.allocine.fr\/skin\/img\/macaron-363298eee7.png"}},"webedia_websites":["allocine.fr","www.academiedugout.fr","www.canalblog.com","www.over-blog.com","www.confidentielles.com","www.750g.com","www.alibabuy.com","www.chartsinfrance.net","www.dailyconso.com","www.easyvols.fr","www.easyvoyage.com","www.exponaute.com","www.forumjv.com","fr.ign.com","jeu.info","www.jeuxvideo.com","www.lebonguide.com","www.lofficielmode.com","www.millenium.org","www.purebreak.com","www.purecine.com","www.purefamille.com","www.purfans.com","www.pureloisirs.com","www.ozap.com","www.purepeople.com","www.puresaveurs.com","www.shopoon.fr","www.puresweethome.com","www.puretrend.com","www.terrafemina.com","www.yasmina.com","www.atyabtabkha.3a2ilati.com","www.3a2ilati.com","www.mashaheeri.com","www.mazyun.com","www.beyazperde.com","www.filmstarts.de","www.moviepilot.de","www.gamestar.de","www.onlinewelten.com","de.ign.com","www.gamespilot.de","www.heimgourmet.com","www.easyvoyage.de","www.adorocinema.com","br.ign.com","www.purepeople.com.br","www.purebreak.com.br","www.pureviagem.com.br","www.tudogostoso.com.br","www.receitas-sem-fronteiras.com","www.easyvoyage.co.uk","www.dealchecker.co.uk","www.gourmandize.com","www.sensacine.com","www.3djuegos.com","es.ign.com","www.easyviajar.com","www.rebanando.com","www.easyviaggio.com","www.tribugolosa.com"],"hosts":{"assets":"https:\/\/assets.allocine.fr","secure":"https:\/\/secure.allocine.fr","secureApi":"https:\/\/api-secure.allocine.fr","validation":"https:\/\/secure.allocine.fr","sso":"https:\/\/sso.allocine.fr","graph":"https:\/\/graph.allocine.fr","hostname":"allocine.fr"},"ads":{"displayProvider":"jad","prerollProvider":"jad","postrollProvider":"wads","postrollProxy":"\/\/videos.allocine.fr","atf":"atf","slideshow":"slideshow","slideshownativebanner":"slideshownativebanner","positions":"dfp-atf,dfp-mtf,dfp-btf,dfp-interstitial,dfp-masthead,,dfp-slideshow,dfp-slideshownativebanner,dfp-sticky-amp,,,dfp-inread,,,,dfp-headerlink,,dfp-autopromo,dfp-pulse,dfp-nativebanner,dfp-nativebanner-ope,dfp-nativerectangle,dfp-nativebutton,dfp-nativevod,"},"secureApiPartnerKey":"000042532791","facebook":{"appId":"99197768694","version":"v3.2","permissions":"public_profile email user_friends"},"google":{"appId":"472230823030.apps.googleusercontent.com","apiKey":"pxKT_spGOdGnt7MVJXcTGCGr","permissions":"https:\/\/www.googleapis.com\/auth\/userinfo.email https:\/\/www.googleapis.com\/auth\/plus.login","tagManagerId":"GTM-PL6PBF","analyticsUACode":"UA-597605-13","analyticsPartners":[],"reCaptchaSiteKey":"6Les8ukZAAAAACSRJMDHQqUcD2iwl1wGq1or2g4S"},"disqus":{"shortname":"allocine-prod2","apiKey":"WmFI6FIX8lZxK1fZdaYuGxizFUoFfJn3iCHfRulxsPNMQOfZwDWbnD0xyjS6fqSR","ssoButton":"https:\/\/fr.web.img1.acsta.net\/commons ...
#     AC.routing = {"base_url":"","routes":{"allocine__moviepage":{"tokens":[["text",".html"],["variable","=","[1-9]\\d*","movie"],["text","\/film\/fichefilm_gen_cfilm"]],"defaults":[],"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes":{"tokens":[["text","\/"],["variable","-","[1-9]\\d*","movie"],["text","\/seance\/film"]],"defaults":[],"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_place":{"tokens":[["part","__urlpart0__",[["text","\/"],["variable","-","[0-9]{1,2}","day"],["text","d"]]],["text","\/"],["variable","-","\\d+","localization"],["text","\/pres-de"],["variable","-","[1-9]\\d*","movie"],["text","\/seance\/film"]],"defaults":{"day":0},"requirements":{"localization":"\\d+","day":"[0-9]{1,2}","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_my_theaters":{"tokens":[["part","__urlpart0__",[["text","\/"],["variable","-","[0-9]{1,2}","day"],["text","d"]]],["text","\/favoris\/seances\/"],["variable","-","[1-9]\\d*","movie"],["text","\/seance\/film"]],"defaults":{"day":0},"requirements":{"day":"[0-9]{1,2}","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_lookup":{"tokens":[["text","\/recherche\/"],["variable","-","[1-9]\\d*","movie"],["text","\/seance\/film"]],"defaults":[],"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_videos_trailer":{"tokens":[["text",".html"],["variable","=","[1-9]\\d*","movie"],["text","&cfilm"],["variable","=","[1-9]\\d*","idMedia"],["text","\/video\/player_gen_cmedia"]],"defaults":[],"requirements":{"idMedia":"[1-9]\\d*","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_all_videos_trailer":{"tokens":[["text","\/toutes\/"],["variable","-","[1-9]\\d*","movie"],["text","\/videos\/fichefilm"]],"defaults":[],"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_casting":{"tokens":[["text","\/casting\/"],["variable","-","[1-9]\\d*","movie"],["text","\/film\/fichefilm"]],"defaults":[],"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_reviews_press":{"tokens":[["text","\/critiques\/presse\/"],["variable","-","[1-9]\\d*","movie"],["text","\/film\/fichefilm"]],"defaults":[],"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_reviews_public":{"tokens":[["part","__urlpart0__",[["text","\/"],["variable","-","[0-5]","starsFilter"],["text","star"]]],["text","\/critiques\/spectateurs\/"],["variable","-","[1-9]\\d*","movie"],["text","\/film\/fichefilm"]],"defaults":[],"requirements":{"starsFilter":"[0-5]","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_reviews_public_recent":{"tokens":[["part","__urlpart0__",[["text","\/"],["variable","-","[0-5]","starsFilter"],["text","star"]]],["text","\/critiques\/spectateurs\/recentes\/"],["variable","-","[1-9]\\d*","movie"],["text","\/film\/fichefilm"]],"defaults":[],"requirements":{"starsFilter":"[0-5]","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_reviews_public_membres":{"tokens":[["part","__urlpart0__",[["text","\/"],["variable","-","[0-5]","starsFilter"],["text","star"]]],["text","\/critiques\/spectateurs\/membres-critiques\/"],["variable","-","[1-9]\\d*","movie"],["text","\/film\/fichefilm"]],"defaults":[],"requirements":{"starsFilter":"[0-5]","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"], ...
#     AC.route = 'homepage';
# }(window));</script>
# <script src="https://assets.allocine.fr/js/website/translations-d5a26019c76322d72d12d32f753ec747.fr_FR.js"></script>
# <script src="https://assets.allocine.fr/js/website/website-common.f0d2a680761eb6e8289d.js" type="text/javascript"></script>
# <script defer="" src="https://assets.allocine.fr/js/website/home.043e21d89a726ca76dc1.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var dataLayer = dataLayer || [{"site_route":"home","site_section":"other"}];
# </script>
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-PL6PBF" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script type="text/javascript">
#             var asyncDataLayers = [];
#             var jsEntities = [];
#         </script>
# <script>
#     (function(win, undefined) {
#         var tests = [];
#
#         // add tests here
#         tests.push(function() {
#             return 'CSS' in win && CSS.supports('display', 'grid');
#         });
#
#         // run all tests
#         var length = tests.length;
#         var idx = 0;
#         var supported = true;
#
#         for (idx = 0; supported && idx < length; idx += 1) {
#             supported = tests[idx]();
#         }
#
#         // display banner
#         if (!supported) {
#             var doc = win.document;
#             var alertBanner = doc.createElement('div');
#             var alertContent = alertBanner.cloneNode('div'); // performence best pratice
#             var bannerText = doc.createTextNode("La version de votre navigateur n'est plus supportée, l'expérience sur le site sera dégradée. Si vous ne pouvez ni mettre à jour votre navigateur, ni en changer, sachez que le site est consultable sur mobile à la même adresse.");
#
#             alertBanner.className = "alert-deprecated-banner alert-info";
#             alertContent.className = "alert-content";
#
#             var body = doc.body;
#             var head = doc.getElementsByTagName('head')[0];
#
#             var header = doc.getElementById('main-header');
#             var link = doc.createElement('link');
#
#             alertContent.appendChild(bannerText);
#             alertBanner.appendChild(alertContent);
#
#             body.insertBefore(alertBanner, header || body.firstChild);
#             body.className += ' deprecated';
#
#             // @todo css deprecated
#             link.setAttribute('href', 'https\u003A\/\/assets.allocine.fr\/skin\/css\/allocine\/deprecated.min\u002D554090a2ab.css');
#             link.setAttribute('rel', 'stylesheet');
#             link.setAttribute('type', 'text/css');
#             head.appendChild(link);
#         }
#     })(window);
# </script>
# </div>
# </body>
# <!-- cTime 16:10:56 -->
# </html>

# %% [markdown]
# On your web browser (Chrome, Firefox,...), you can use the "inspect" function (right click -> inspect) and drag your mouse to the areas of the page that interest you. At the same time I will see the html script move to the instructions of the html script in question.
#
# That's how you find the tags that you are interested in.

# %% [markdown]
# I notice that the relative link of the web page specific to the new movie on the poster is stored in these tags:
#
# ```html
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=235582.html" title="Le Grand Bain">Le Grand Bain</a>
# ```

# %%
for p in soup.find_all('a'):
    print (p.text)
# Out:
# Un homme en colère
# West Side Story
# Lucifer
# The Resident
#
#             Cinéma
#
#
#             Séries
#
#
#             Trailers
#
#
#             DVD
#
#
#             VOD
#
#
#                         Kids
#
# séances cinéma
# news
# dossiers
# émissions AlloCiné
# dernières bandes-annonces
# Meilleurs films
# Meilleurs films pour enfants
# Meilleurs documentaires
# Tous les films
# Meilleurs films 2019
# Tous les films pour enfants
# Avant-premières
# Agenda des sorties
# Films pour enfants à l'affiche
# Box Office
# Bandes-annonces à ne pas manquer
# Army Of The Dead
# Army of the Dead Bande-annonce VF
# Fast & Furious 9 Bande-annonce VO
# Top Gun: Maverick Bande-annonce (2) VO
# Hitman & Bodyguard Bande-annonce VO
# Shadow in the Cloud Teaser VO
#  Fast & Furious 9
#  Nomadland
#
#  Godzilla vs Kong
#
#  Space Jam - Nouvelle ère
#
#
# Tous les films à venir
# Dernières news cinéma
# Godzilla vs Kong privé de sortie cinéma
# Le Chant du Loup sur M6 : François Civil et Omar Sy ont-ils tourné dans de vrais sous-marins ?
# Raya et le dernier dragon sera diffusé en exclusivité sur Disney+
# Fermeture des salles : aller au cinéma manque à 63 % des Français
# Scream : la méthode insolite des cinéastes pour éviter les spoilers
# Fast & Furious 9 : un crossover avec Jurassic Park ? Justin Lin est partant !
# Tous les dossiers cinéma
# Tous les films encore à l'affiche
# Disney+
# Netflix
# Amazon Prime Video
# Canal+
# OCS
# Sisyphus sur Netflix : c’est quoi cette ambitieuse série SF sud-coréenne ?
# Hippocrate, l'oreille internes sur myCANAL : immersion passionnante dans le quotidien d’étudiants en médecine
# Un Si Grand Soleil : Enric va-t-il avouer son infidélité à Mo ? [SPOILERS]
# Cosmic Sin sur Prime Vidéo : on a rencontré la nouvelle voix de Bruce Willis
# Séries à voir  sur CANAL+
# Hippocrate
# Your Honor
# Vikings
# This is Us
# It's a Sin
# Meilleures séries  sur Netflix
# Breaking Bad
# Notre planète
# Peaky Blinders
# L' Attaque des Titans
# Le jeu de la dame
# Films disponibles  sur Disney+
# Le Labyrinthe
# Ant-Man
# Soul
# Vaiana, la légende du bout du monde
# Titanic
# Films disponibles sur Amazon Prime Video
# Je te veux, moi non plus
# Cosmic Sin
# Un prince à New York 2
# Wonder Boys
# Les derniers films en VOD
# Wonder Woman 1984
# Zack Snyder's Justice League
# Les dernières séries en VOD
# The First
# Rectify
# The Night Manager
# Sorties DVD & Blu-Ray
# Songbird
# Cousins
# Becky
# Meilleures séries
# Episodes inédits ce soir à la TV
# Séries tv inédites à voir
# Nouvelles saisons attendues
# Toutes les séries
# Dernières vidéos de séries
# Episodes inédits à la TV demain
# Toutes les vidéos de séries
# Tous les teasers de séries
# Top séries de la semaine
# Le Serpent
# Le Remplaçant
# Qui a tué Sara ?
# Les séries les plus attendues
# L'Ecole de la vie
# Jupiter's Legacy
# HPI
# Shadow and Bone
# L'actu séries
# Dix pour cent : la saison 5 pourrait être un reboot
# Netflix : Nawell Madani présente sa première série, Bendo
# Fun Facts
# Faux raccord
# Fanzone
# Aviez-vous remarqué ?
# Give Me Five
# The Big Fan Theory
# AlloCiné Zap
# AlloCiné Séries
# Top 5
# Ma scène préférée
# Stars
# Toutes les stars françaises
# Toutes les stars américaines
# Top stars complet
# Bandes originales
# Musique de films
# Musique de séries TV
# News jeux vidéo
# Filmstarts
# Beyazperde
# SensaCine España
# SensaCine México
# Adorocinema
# Préférences cookies
#
# Back to Top

# %% [markdown]
# This time, the site is more difficult to "extract". Let's use much more specific parameters to the search function `find_all`.

# %%
# In addition to the tag a, which is easily identifiable, we notice some additional 
# information such as the value of the class variable of these identical tags.
for elem in soup.find_all('a',attrs={"class" :"meta-title meta-title-link"}):
    print(elem)
# Out:
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=25362.html" title="Le Serpent">Le Serpent</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=27414.html" title="Le Remplaçant">Le Remplaçant</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=28562.html" title="Qui a tué Sara ?">Qui a tué Sara ?</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=27142.html" title="L'Ecole de la vie">L'Ecole de la vie</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=23853.html" title="Jupiter's Legacy">Jupiter's Legacy</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=25616.html" title="HPI">HPI</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=24647.html" title="Shadow and Bone">Shadow and Bone</a>

# %% [markdown]
# #### Recovery of `href`

# %% [markdown]
# We have noticed the presence of `href` links to the pages that interest us. Let's go get them back:

# %%
for elem in soup.find_all('a',attrs={"class" :"meta-title meta-title-link"}):
    print(elem.get('href'))
    # return a list
# Out:
# /series/ficheserie_gen_cserie=25362.html
# /series/ficheserie_gen_cserie=27414.html
# /series/ficheserie_gen_cserie=28562.html
# /series/ficheserie_gen_cserie=27142.html
# /series/ficheserie_gen_cserie=23853.html
# /series/ficheserie_gen_cserie=25616.html
# /series/ficheserie_gen_cserie=24647.html

# %% [markdown]
# Can you retrieve the titles for me via the search for "title" in the items of the previous list?

# %%
for elem in soup.find_all('a',attrs={"class" :"meta-title meta-title-link"}):
    print(elem.get('title'))
# Out:
# Le Serpent
# Le Remplaçant
# Qui a tué Sara ?
# L'Ecole de la vie
# Jupiter's Legacy
# HPI
# Shadow and Bone

# %% [markdown]
# #### Get summary

# %% [markdown]
# Let's start by building the url that we will use to retrieve the summaries
#
# Start by putting the `href` values in a list of links

# %%
links=[]
for elem in soup.find_all('a',attrs={"class" :"meta-title meta-title-link"}):
    # I simply put all of thisin a list
    links.append(elem.get('href'))
links
# Out:
# ['/series/ficheserie_gen_cserie=25362.html',
#  '/series/ficheserie_gen_cserie=27414.html',
#  '/series/ficheserie_gen_cserie=28562.html',
#  '/series/ficheserie_gen_cserie=27142.html',
#  '/series/ficheserie_gen_cserie=23853.html',
#  '/series/ficheserie_gen_cserie=25616.html',
#  '/series/ficheserie_gen_cserie=24647.html']

# %% [markdown]
# The absolute url of the searched movie pages is built in this form: http://www.allocine.fr/film/fichefilm_gen_cfilm=243835.html
#
# It is therefore necessary to repeat the previous list and build the absolute urls for our search
#
# It's up to you to play.
#
# NB: Do not take the links for the shows(series)

# %%
links_movie=['http://www.allocine.fr'+ elem for elem in links if 'series' in elem]
links_movie
# Out:
# ['http://www.allocine.fr/series/ficheserie_gen_cserie=25362.html',
#  'http://www.allocine.fr/series/ficheserie_gen_cserie=27414.html',
#  'http://www.allocine.fr/series/ficheserie_gen_cserie=28562.html',
#  'http://www.allocine.fr/series/ficheserie_gen_cserie=27142.html',
#  'http://www.allocine.fr/series/ficheserie_gen_cserie=23853.html',
#  'http://www.allocine.fr/series/ficheserie_gen_cserie=25616.html',
#  'http://www.allocine.fr/series/ficheserie_gen_cserie=24647.html']

# %% [markdown]
# Finally, on each page, the title and synopsis must be retrieved. Let's try for a movie, the first of the list

# %%
url=links_movie[0]
r = requests.get(url)
print(url, r.status_code)
soup = BeautifulSoup(r.content,'lxml')
soup
# Out:
# http://www.allocine.fr/series/ficheserie_gen_cserie=25362.html 200
# <!DOCTYPE html>
# <html lang="fr">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="index,follow,max-snippet:-1,max-image-preview:large" name="robots"/>
# <title>Le Serpent - Série TV 2020 - AlloCiné</title>
# <meta content="" name="keywords"/>
# <meta content="noarchive" name="Googlebot"/>
# <meta content="global" name="distribution"/>
# <meta content="AlloCine" name="author"/>
# <meta content="France" name="country"/>
# <meta content="48.87078;2.30447" name="geo.position"/>
# <meta content="FR" name="geo.country"/>
# <meta content="48.87078;2.30447" name="ICBM"/>
# <meta content="#FECC00" name="theme-color"/>
# <meta content="Le Serpent est une série TV de Richard Warlow et Toby Finlay avec Tahar Rahim (Charles Sobhraj), Jenna Coleman (Marie-Andrée Leclerc). Retrouvez toutes les news et les vidéos de la série Le Serpent. Synopsis : L'histoire de l’escroc Charles Sobhraj et les tentatives remarquables du diplomate néerlandais Herma..." name="description"/>
# <meta content="AlloCiné" property="og:site_name"/>
# <meta content="Le Serpent" property="og:title"/>
# <meta content="Le Serpent est une série TV de Richard Warlow et Toby Finlay avec Tahar Rahim (Charles Sobhraj), Jenna Coleman (Marie-Andrée Leclerc). Retrouvez toutes les news et les vidéos de la série Le Serpent. Synopsis : L'histoire de l’escroc Charles Sobhraj et les tentatives remarquables du diplomate néerlandais Herma..." property="og:description"/>
# <meta content="https://fr.web.img5.acsta.net/pictures/21/03/04/16/06/5540747.jpg" property="og:image"/>
# <meta content="video.tv_show" property="og:type"/>
# <meta content="99197768694" property="fb:app_id"/>
# <meta content="photo" name="twitter:card"/>
# <meta content="@allocine" name="twitter:site"/>
# <meta content="Le Serpent" name="twitter:title"/>
# <meta content="Le Serpent est une série TV de Richard Warlow et Toby Finlay avec Tahar Rahim (Charles Sobhraj), Jenna Coleman (Marie-Andrée Leclerc). Retrouvez toutes les news et les vidéos de la série Le Serpent. Synopsis : L'histoire de l’escroc Charles Sobhraj et les tentatives remarquables du diplomate néerlandais Herma..." name="twitter:description"/>
# <meta content="https://fr.web.img5.acsta.net/pictures/21/03/04/16/06/5540747.jpg" name="twitter:image"/>
# <meta content="allocine" name="twitter:app:name:iphone"/>
# <meta content="allocine" name="twitter:app:name:ipad"/>
# <meta content="allocine" name="twitter:app:name:googleplay"/>
# <meta content="allocine://open/tvseries?code=25362" name="twitter:app:url:iphone"/>
# <meta content="allocine://open/tvseries?code=25362" name="twitter:app:url:ipad"/>
# <meta content="allocine://open/tvseries?code=25362" name="twitter:app:url:googleplay"/>
# <meta content="351184863" name="twitter:app:id:iphone"/>
# <meta content="351184863" name="twitter:app:id:ipad"/>
# <meta content="com.allocine.androidapp" name="twitter:app:id:googleplay"/>
# <meta content="app-id=351184863, app-argument=allocine://open/tvseries?code=25362" name="apple-itunes-app"/>
# <meta content="107276450147" property="fb:pages"/>
# <link href="https://assets.allocine.fr" rel="preconnect"/>
# <link as="font" crossorigin="" href="https://assets.allocine.fr/skin/font/icon/font-icon-fec771a6e4.woff2" rel="preload" type="font/woff2"/>
# <link as="image" href="https://assets.allocine.fr/skin/img/allocine/logo-main-grey-32f06844b4.svg" rel="preload" type="image/svg+xml"/>
# <link as="script" href="https://assets.allocine.fr/js/website/website-common.f0d2a680761eb6e8289d.js" rel="preload"/>
# <link as="script" href="https://assets.allocine.fr/js/website/seriespage.4e98b7c6928ae539bd99.js" rel="preload"/>
# <link as="image" href="https://fr.web.img3.acsta.net/c_310_420/pictures/21/03/04/16/06/5540747.jpg" rel="preload"/>
# <style>article,aside,details,figcaption,figure,footer,header,hgroup,nav,section,summary{display:block}audio,canvas,video{display:inline-block}audio:not([controls]){display:none;height:0}[hidden],template{display:none}html{background:#fff;color:#000;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%}button,html,input,select,textarea{font-family:sans-serif}body{margin:0}a{background:transparent}a:focus{outline:thin dotted}a:active,a:hover{outline:0}abbr[title]{border-bottom:1px dotted}b,strong{font-weight:700}dfn{font-style:italic}mark{background:#ff0;color:#000}code,kbd,pre,samp{font-family:monospace,serif;font-size:1em}pre{white-space:pre;white-space:pre-wrap;word-wrap:break-word}q{quotes:"\201C" "\201D" "\2018" "\2019"}q:after,q:before{content:"";content:none}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sup{top:-.5em}sub{bottom:-.25em}img{border:0}svg:not(:root){overflow:hidden}figure{margin:0}fieldset{border:1px solid #ececec;margin:0 2px;padding:.35em .625em .75em}legend{border:0;padding:0;white-space:normal}button,input,select,textarea{font-family:inherit;font-size:100%;margin:0;vertical-align:baseline}button,input{line-height:normal}button,select{text-transform:none}button,html input[type=button],input[type=reset],input[type=submit]{-webkit-appearance:button;cursor:pointer}button[disabled],input[disabled]{cursor:default}input[type=checkbox],input[type=radio]{box-sizing:border-box;padding:0}input[type=search]{-webkit-appearance:textfield;box-sizing:content-box}input[type=search]::-webkit-search-cancel-button,input[type=search]::-webkit-search-decoration{-webkit-appearance:none}button::-moz-focus-inner,input::-moz-focus-inner{border:0;padding:0}textarea{overflow:auto;vertical-align:top}table{border-collapse:collapse;border-spacing:0}em{font-style:normal}*,:after,:before{box-sizing:border-box}::-moz-selection{background:#b3d4fc;text-shadow:none}::selection{background:#b3d4fc;text-shadow:none}input:focus{outline:none}p{margin:0}h1,h2,h3,h4,h5,h6{margin:0;padding:0;font-size:1em}hr{display:block;height:1px;border:0;margin:1em 0;padding:0}audio,canvas,img,video{vertical-align:middle}fieldset,textarea{border:0;margin:0;padding:0}textarea{resize:vertical;outline:0;font-size:13px;width:100%}li,ol,ul{list-style:none;margin:0;padding:0}address{font-style:normal}iframe{border:0}.alert:before,.dropdown-custom .btn,.dropdown-select:after,.icon:after,.icon:before,.more-trigger:after,.rating-star:before{font-family:font-icon;font-style:normal;font-weight:400;font-variant:normal;text-transform:none;speak:none;display:inline-block;vertical-align:middle;margin:0 .375rem;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.icon:after{margin-right:0}.icon:before{margin-left:0}.icon{font-size:1rem}.no-icon{display:none}.icon-centered:after,.icon-centered:before{margin:auto}@font-face{font-family:font-icon;src:url(https://assets.allocine.fr/skin/font/icon/font-icon-fec771a6e4.woff2) format("woff2"),url(https://assets.allocine.fr/skin/font/icon/font-icon-87118fa3de.woff) format("woff"),url(https://assets.allocine.fr/skin/font/icon/font-icon-8c2879c3a6.ttf) format("truetype");font-weight:400;font-style:normal}.footer-logo-WB{background-position:-284px 0;width:112px;height:29px}.footer-logo-boxoffice{background-position:-925px 0;width:315px;height:26px}.footer-logo{background-position:-398px 0;width:120px;height:34px}.header-arrow--bottom--black{background-position:0 0;width:16px;height:16px}.header-back{background-position:-92px 0;width:46px;height:46px}.header-burger{background-position:-140px 0;width:46px;height:46px}.header-home{background-position:-18px 0;width:16px;height:16px}.header-logo--primary{background-position:-661px 0;width:262px;height:74px}.header-logo-userspace{background-position:-520px 0;width:139px;height:39px}.header-minify{background-position:-188px 0;width:46px;height:46px}.header-music{background-position:-36px 0;width:16px;height:16px ...
# <script type="text/javascript">
# !function(a){var c="rcblock",e="rc-ko",t=localStorage.getItem(c);t===e&&(document.getElementsByTagName("html")[0].classList.add("m-ac-g-a"),a.RCBLOCK=!0)}(window);
# </script>
# <script type="text/javascript">
# (function(global) {
#     var fontStyleKey      = 'font_css_code';
#     var fontCssUrlKey     = 'font_css_url';
#     var brand             = 'allocine';
#     var fontCss           = localStorage.getItem(fontStyleKey);
#     var distantFontHash   = localStorage.getItem(fontCssUrlKey);
#     var currentFontHash   = 'https\u003A\/\/assets.allocine.fr\/skin\/css\/allocine\/font.min\u002Dc4d149dbf5.css';
#
#     if (fontCss && distantFontHash && (distantFontHash === currentFontHash)) {
#         var style           = document.createElement('style');
#             style.type      = 'text/css';
#             style.innerHTML = fontCss;
#
#       document.head.appendChild(style);
#
#       global.AC_FONT_LOADED = true;
#     }
# }(window));
# </script>
# <link href="https://assets.allocine.fr/favicon/allocine.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://assets.allocine.fr/favicon/allocine.ico" rel="icon" type="image/ico"/>
# <link href="https://assets.allocine.fr/apple-touch-icon/allocine.png" rel="apple-touch-icon"/>
# <link href="https://twitter.com/allocine" rel="me"/>
# </head>
# <body class="allocine allocine__seriespage logged-out" id="allocine__seriespage">
# <div class="sub-body">
# <div class="js-interstitial ad-interstitial ad-item" id="dfp-interstitial"></div>
# <header class="header-main" id="header-main">
# <div class="header-main-center">
# <div class="header-main-top">
# <div aria-label="Bouton Menu mobile" class="header-main-btn-mobile icon icon-hamburger" id="header-main-mobile-btn-menu"></div>
# <div class="header-main-logo-holder">
# <span class="ACrLw=ACr= header-main-logo">
# <img alt="allocine" class="header-main-logo-img" height="37" src="https://assets.allocine.fr/skin/img/allocine/logo-main-12195cd9d9.svg" width="162"/>
# <span class="header-main-logo-name">AlloCiné</span>
# </span>
# </div>
# <form action="/rechercher/" class="header-main-search" id="search-header" method="get">
# <fieldset class="header-main-search-fieldset" id="search-engine">
# <div class="header-search-form-container"><input class="header-search-input" id="header-search-input" name="q" placeholder="Rechercher un film, une série, une star..." type="text"/><button aria-label="Envoyer" class="header-search-submit icon icon-search" title="Rechercher" type="submit"></button></div> </fieldset>
# <p class="header-search-extralinks">
#                         Ex. :
#                         <span class="ACrL3NACrlcmllcy9maWNoZXNlcmllX2dlbl9jc2VyaWU9NzE1Ny5odG1s">Game of thrones</span>, <span class="ACrL3NACrlcmllcy9maWNoZXNlcmllX2dlbl9jc2VyaWU9MTAzNjguaHRtbA==">Orange is the new black</span>, <span class="ACrL3NACrlcmllcy9maWNoZXNlcmllX2dlbl9jc2VyaWU9NDUxLmh0bWw=">Prison break</span> </p>
# <div class="header-main-search-mobile-layer" id="header-main-search-mobile-layer"></div>
# </form>
# <div class="header-ads-zone">
# <div class="js-headerlink ad-headerlink ad-item" id="dfp-headerlink"></div>
# </div>
# <div aria-label="Bouton Rechercher" class="header-main-btn-mobile icon icon-search" id="header-main-mobile-btn-search"></div>
# <span aria-label="Bouton Notez des films" class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIvc3BlZWRub3Rlci9jdWx0LW1vdmllcy8= button button-default-full button-sm icon icon-star-empty button-permanent-speednoter" data-ga='{"eventCategory":"my_brand","eventAction":"header_button","eventLabel":"entities_list"}' data-ga-trigger="clic">
# <span class="button-permanent-speednoter-text">Notez des films</span>
# </span>
# <div class="header-main-btn-mobile header-main-mobile-btn-userspace" id="header-main-mobile-btn-userspace">
# <span aria-label="Bouton Mon AlloCiné" class="icon icon-profil"></span>
# <img alt="" class="avatar js-myaccount-avatar" src="..."/>
# </div>
# </div>
# <div class="header-main-bottom">
# <nav class="header-main-nav" id="header-main-nav"><ul class="header-nav-holder"><li class="header-nav-item"><span class="ACrL2ZACrpbG0v header-nav-link" title="Cinéma">
#             Cinéma
#         </span></li><li class="header-nav-item is-active"><span class="ACrL3NACrlcmllcy8= header-nav-link current" title="Séries">
#             Séries
#         </span><div class="header-main-subnav-holder"><ul class="header-main-subnav"><li class="header-subnav-item"><span class="ACrL3NACrlcmllcy90b3Av header-nav-link" title="Tops séries">
#             Tops séries
#         </span></li><li class="header-subnav-item"><span class="ACrL3NACrlcmllcy9ub3V2ZWxsZXMvYXR0ZW5kdWVzLw== header-nav-link" title="Nouvelles séries">
#             Nouvelles séries
#         </span></li><li class="header-subnav-item"><span class="ACrL3NACrlcmllcy9yZW5vdXZlbGVlcy9hdHRlbmR1ZXMv header-nav-link" title="Séries renouvelées">
#             Séries renouvelées
#         </span></li><li class="header-subnav-item"><span class="ACrL3NACrlcmllcy9ndWlkZS9lcGlzb2Rlcy8= header-nav-link" title="Guide des épisodes">
#             Guide des épisodes
#         </span></li><li class="header-subnav-item"><span class="ACrL3NACrlcmllcy10di8= header-nav-link" title="Toutes les séries">
#             Toutes les séries
#         </span></li></ul></div></li><li class="header-nav-item"><span class="ACrL3NACr0cmVhbWluZy8= header-nav-link" data-ga='{"hitType":"event","eventCategory":"op-svod","eventLabel":"https:\/\/www.allocine.fr\/series\/ficheserie_gen_cserie=25362.html","eventAction":"navigation_menu_click"}' data-ga-trigger="clic" title="Streaming">
#             Streaming
#         </span></li><li class="header-nav-item"><span class="ACrL25ACrld3Mv header-nav-link" title="News">
#             News
#         </span></li><li class="header-nav-item"><span class="ACrL3RACryYWlsZXIv header-nav-link" title="Trailers">
#             Trailers
#         </span></li><li class="header-nav-item"><span class="ACrL2RACr2ZC8= header-nav-link" title="DVD">
#             DVD
#         </span></li><li class="header-nav-item"><span class="ACrL3ZACrvZC8= header-nav-link" title="VOD">
#             VOD
#         </span></li><li class="header-nav-item"><span class="ACrL2tACrpZHMv header-nav-link" data-ga='{"hitType":"event","eventCategory":"op-kids","eventLabel":"https:\/\/www.allocine.fr\/series\/ficheserie_gen_cserie=25362.html","eventAction":"navigation_menu_click"}' data-ga-trigger="clic" title="Kids">
#                         Kids
#                     </span></li><li class="header-nav-item"><span class="ACrL2RACrpc25leS8= header-nav-link-disney header-nav-link" data-ga='{"hitType":"event","eventCategory":"op-disneyplus","eventLabel":"https:\/\/www.allocine.fr\/series\/ficheserie_gen_cserie=25362.html","eventAction":"navigation_menu_click","dimension81":"2021-04-15"}' data-ga-trigger="clic" title="Disney+"><i class="header-nav-logo-disney"></i>DISNEY<span class="disney-plus">+</span></span></li></ul></nav><div class="header-userspace-nav" id="header-userspace-nav"><span aria-label="Bouton Mon AlloCiné" class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIv header-nav-userspace-upper-link"><span class="icon icon-profil"></span><img alt="" class="avatar js-myaccount-avatar" src="..."/>
#                     Mon AlloCiné
#                 </span><div class="header-nav-userspace-holder"><div class="header-nav-userspace-sso"><span class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIvY29ubmV4aW9uLz9yZXR1cm5Vcmw9aHR0cHMlM0ElMkYlMkZ3d3cuYWxsb2NpbmUuZnIlMkZzZXJpZXMlMkZmaWNoZXNlcmllX2dlbl9jc2VyaWUlM0QyNTM2Mi5odG1s button button-social-ac-ghost button-sm sign-in"><span class="txt">Identifiez-vous</span></span><span class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIvaW5zY3JpcHRpb24vP3JldHVyblVybD0lMkYlMkZtb24uYWxsb2NpbmUuZnIlMkY= button button-social-ac-full button-sm sign-up"><span class="txt">Créez votre compte</span></span></div><ul class="header-nav-userspace-subcontent"></ul></div></div> </div>
# </div>
# </header>
# <div class="main-banner">
# <div class="js-masthead ad-masthead ad-item" id="dfp-masthead"></div>
# </div>
# <main class="row content-layout entity series cf" id="content-layout">
# <div class="section-wrap breadcrumb">
# <a class="item" href="/">Accueil</a><a class="item" href="/series/">Séries</a><a class="item" href="/series-tv/">Séries TV les plus populaires</a><a class="item" href="/series-tv/genre-13008/">Séries Drame</a><h1 class="item">
#     Le Serpent    </h1></div>
# <section class="section-wrap">
# <div class="titlebar titlebar-page"><div class="titlebar-title titlebar-title-lg"><span class="ACrL3NACrlcmllcy9maWNoZXNlcmllX2dlbl9jc2VyaWU9MjUzNjIuaHRtbA== titlebar-link">Le Serpent</span></div><div class="js-affinity-badge titlebar-btn-holder" data-entity-id="U2VyaWVzOjI1MzYy"></div></div>
# </section>
# <nav class="third-nav third-nav-tab js-third-nav">
# <span class="ACrL3NACrlcmllcy9maWNoZXNlcmllX2dlbl9jc2VyaWU9MjUzNjIuaHRtbA== home item current" title="Fiche série">
# <div class="icon icon-home item-center"></div>
# </span>
# <span class="ACrL3NACrlcmllcy9maWNoZXNlcmllLTI1MzYyL3NhaXNvbnMv item" title="Saisons et Episodes">
# <div class="item-center">Saisons et Episodes</div>
# </span>
# <span class="ACrL3NACrlcmllcy9maWNoZXNlcmllLTI1MzYyL2Nhc3Rpbmcvc2Fpc29uLTM2NTQ1Lw== item" title="Casting">
# <div class="item-center">Casting</div>
# </span>
# <a class="item js-item-mq-medium" href="/series/ficheserie-25362/videos/" title="Vidéos">
# <div class="item-center">Vidéos</div>
# </a>
# <span class="ACrL3NACrlcmllcy9maWNoZXNlcmllLTI1MzYyL25ld3Mv item js-item-mq-medium" title="News">
# <div class="item-center">News</div>
# </span>
# <a class="item js-item-mq-medium" href="/series/ficheserie-25362/critiques/" title="Critiques">
# <div class="item-center">Critiques</div>
# </a>
# <span class="item inactive">
# <div class="item-center">Diffusion TV</div>
# </span>
# <span class="item js-item-mq-medium inactive">
# <div class="item-center">VOD</div>
# </span>
# <div class="item-more js-third-sub-nav-holder">
# <span class="item-more-picto icon icon-plus js-trigger-third-nav-sub"></span>
# <div class="third-nav-sub js-third-nav-sub">
# <span class="item inactive">
# <div class="item-center">Blu-Ray, DVD</div>
# </span>
# <span class="item inactive">
# <div class="item-center">Récompenses</div>
# </span>
# <span class="item inactive">
# <div class="item-center">Musique</div>
# </span>
# <span class="ACrL3NACrlcmllcy9maWNoZXNlcmllLTI1MzYyL3Bob3Rvcy8= item" title="Photos">
# <div class="item-center">Photos</div>
# </span>
# <span class="item inactive">
# <div class="item-center">Secrets de tournage</div>
# </span>
# <span class="item inactive">
# <div class="item-center">Séries similaires</div>
# </span>
# <span class="item inactive">
# <div class="item-center">Audiences</div>
# </span>
# </div>
# </div>
# </nav>
# <section class="section section-wrap gd-2-cols gd-gap-30">
# <div class="gd-col-left">
# <div class="js-nativebanner ad-nativebanner ad-item" id="dfp-nativebanner"></div>
# <div class="js-nativerectangle ad-nativerectangle ad-item" id="dfp-nativerectangle"></div>
# <div class="card entity-card entity-card-overview entity-card-list cf">
# <figure class="thumbnail">
# <span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTkxNTMyJmNzZXJpZT0yNTM2Mi5odG1s thumbnail-container thumbnail-link" title="Le Serpent">
# <img alt="Le Serpent" class="thumbnail-img" height="420" src="https://fr.web.img3.acsta.net/c_310_420/pictures/21/03/04/16/06/5540747.jpg" width="310"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# <div class="label label-text label-sm label-danger-full label-status">Terminée</div>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-body">
# <div class="meta-body-item meta-body-info">
#
#
#
#
#
#                 2020 - 2021
#
#                                 <span class="spacer">/</span>
#
#
#                                     60min
#
#                                     <span class="spacer">/</span>
# <span class="ACrL3NACrlcmllcy10di9nZW5yZS0xMzAwOC8=">Drame</span>,
#                                                                                                                             <span class="ACrL3NACrlcmllcy10di9nZW5yZS0xMzAxOC8=">Policier</span>,
#                                                                                                                             <span class="ACrL3NACrlcmllcy10di9nZW5yZS0xMzAyMy8=">Thriller</span>,
#                                                                                                                             <span class="ACrL3NACrlcmllcy10di9nZW5yZS0xMzAyNy8=">Biopic</span>
# </div>
# <div class="meta-body-item meta-body-original-title">
# <span class="light">Titre original :</span>
# <strong>The Serpent</strong>
# </div>
# <div class="meta-body-item meta-body-direction">
# <span class="light">De</span>
# <a class="blue-link" href="/personne/fichepersonne_gen_cpersonne=241389.html">Richard Warlow</a>,
#
#                                                                                     <a class="blue-link" href="/personne/fichepersonne_gen_cpersonne=399861.html">Toby Finlay</a>
# </div>
# <div class="meta-body-item meta-body-actor">
# <span class="light">Avec</span>
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT0xNzE4OTkuaHRtbA==">Tahar Rahim</span>,
#
#
#                                                                                     <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT0yMjkzMDcuaHRtbA==">Jenna Coleman</span>,
#
#
#                                                                                     <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT02ODEwNjMuaHRtbA==">Billy Howle</span>
# </div>
# <div class="meta-body-item meta-body-nationality">
# <span class="light">Nationalité</span>
# <span class="ACrL3NACrlcmllcy10di9wYXlzLTUwMDQv nationality"> Grande-Bretagne</span>
# </div>
# </div>
# </div>
# <div class="buttons-holder">
# <span class="ACrL2pACr1bXAv#data-affiliation-type=svod&amp;data-provider=netflix&amp;data-entity-type=Series&amp;data-entity-id=25362 button button-sm button-netflix-full" data-ga='{"hitType":"event","eventCategory":"op-netflix","eventLabel":"see_on_provider_button","dimension82":"25362-le_serpent","dimension10":"seriespage"}' data-ga-non-interaction="1" data-ga-trigger="clic" rel='"noopener"' target="_blank">
# <span class="txt">Voir sur Netflix</span>
# </span>
# </div>
# <div class="rating-holder rating-holder-3">
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3NACrlcmllcy9maWNoZXNlcmllLTI1MzYyL2NyaXRpcXVlcy9wcmVzc2Uv rating-title"> Presse </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n35 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,3</span><span class="stareval-review light"> 9 critiques</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL3NACrlcmllcy9maWNoZXNlcmllLTI1MzYyL2NyaXRpcXVlcy8= rating-title"> Spectateurs </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n40 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">4,0</span><span class="stareval-review light"> 439 notes dont 79 critiques</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content js-user-friends-rating" data-entity-id="U2VyaWVzOjI1MzYy" data-size="medium" data-title="Mes amis ">
# <a class="rating-title" href="#">Mes amis </a>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
# </div>
# </div>
# </div>
# </div>
# <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">noter :</span><div class="js-user-rating" data-entity-id="U2VyaWVzOjI1MzYy" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="Envie de voir" data-entity-id="U2VyaWVzOjI1MzYy" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">Envie de voir</span></div><div class="bam-cell bam-review js-user-review-link" data-classes="button icon icon-pen" data-content="Rédiger ma critique" data-entity-id="U2VyaWVzOjI1MzYy"><span class="button icon icon-pen">Rédiger ma critique</span></div><div class="bam-cell bam-share"><div class="more-overlay js-more-overlay"><div class="more-overlay-trigger js-more-overlay-button"><div class="icon icon-3dots"></div></div><div class="more-overlay-content"><ul class="more-overlay-subcontent"><li class="more-overlay-item icon icon-add-to-collections js-add-to-collection" data-entity-id="U2VyaWVzOjI1MzYy">Ajouter à une collection</li></ul><span aria-label="Partager ce contenu sur Whatsapp" class="ACraHRACr0cHM6Ly9hcGkud2hhdHNhcHAuY29tL3NlbmQ/dGV4dD1odHRwcyUzQSUyRiUyRnd3dy5hbGxvY2luZS5mciUyRnNlcmllcyUyRmZpY2hlc2VyaWVfZ2VuX2NzZXJpZSUzRDI1MzYyLmh0bWw= button button-whatsapp-full js-share-btn more-overlay-button"><span class="txt">Partager sur WhatsApp</span></span><span aria-label="Partager ce contenu sur Facebook" class="... button button-fb-full js-share-btn more-overlay-button"><span class="txt">Partager sur Facebook</span></span><span aria-label="Partager ce contenu sur Twitter" class="ACraHRACr0cHM6Ly90d2l0dGVyLmNvbS9pbnRlbnQvdHdlZXQ/dGV4dD1MZSUyMFNlcnBlbnQmdXJsPWh0dHBzJTNBJTJGJTJGd3d3LmFsbG9jaW5lLmZyJTJGc2VyaWVzJTJGZmljaGVzZXJpZV9nZW5fY3NlcmllJTNEMjUzNjIuaHRtbCZ2aWE9YWxsb2NpbmU= button button-tw-full js-share-btn more-overlay-button"><span class="txt">Partager sur Twitter</span></span></div></div></div></div>
# <div class="js-affinity-suggestions" data-entity-id="U2VyaWVzOjI1MzYy"></div>
# <div class="js-nativevod ad-nativevod ad-item" id="dfp-nativevod"></div>
# <section class="section ovw ovw-synopsis" id="synopsis-details">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md">Synopsis &amp; Info</h2></div>
# <div class="content-txt">
#                       L'histoire de l’escroc Charles Sobhraj et les tentatives remarquables du diplomate néerlandais Herman Knippenberg pour le traduire en justice. Se faisant passer pour un négociant en pierres précieuses, Charles Sobhraj et sa compagne Marie-Andrée Leclerc voyagent à travers la Thaïlande, le Népal et l’Inde entre 1975 et 1976, commettant sur leur passage une série de crimes sur le « Hippie Trail» asiatique.
#
#             </div>
# <div class="stats-numbers-row stats-numbers-seriespage">
# <div class="stats-numbers-row-item">
# <div class="stats-number">1</div>
# <div class="stats-info">Saison</div>
# </div>
# <div class="stats-numbers-row-item">
# <div class="stats-number">8</div>
# <div class="stats-info">Episodes</div>
# </div>
# </div>
# <a class="end-section-link" href="/series/ficheserie-25362/saison-36545/" title="Voir la Saison 1">Voir la Saison 1</a>
# </section>
# <section class="section ovw" id="ovw-products">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md">Comment regarder cette série</h2></div>
# <div class="ovw-product-item ovw-svod">
# <div class="titlebar"><div class="titlebar-title titlebar-title-sm">En SVOD / Streaming</div></div>
# <ul class="gd gd-gap-10 gd-xs-2 gd-s-6">
# <li class="product-card-online">
# <span class="ACrL2pACr1bXAv#data-affiliation-type=svod&amp;data-provider=netflix&amp;data-entity-type=Series&amp;data-entity-id=25362 product-card-online-inner product-card-online-streaming" data-ga='{"hitType":"event","eventAction":"provider_website_link_button","eventCategory":"netflix","eventLabel":"25362-le_serpent"}' data-ga-trigger="clic" target="_blank">
# <figure class="product-card-online-visu">
# <img alt="netflix" class="logo" data-src="https://fr.web.img5.acsta.net/commons/v9/common/svod_providers/square-netflix.png" src="..."/>
# </figure>
# <div class="info-holder">
# <span class="info-holder-provider">Netflix</span>
# <span class="info-holder-link">Abonnement</span>
# </div>
# </span>
# </li>
# </ul>
# </div>
# </section>
# <div id="mobile-referrer-atf"></div>
# <section class="section ovw">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md"><a class="titlebar-link" href="/series/ficheserie-25362/casting/saison-36545/">Casting</a></h2></div>
# <div class="gd gd-gap-15 gd-xs-2 gd-s-4">
# <div class="card person-card person-card-col">
# <figure class="thumbnail">
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT0xNzE4OTkuaHRtbA== thumbnail-container thumbnail-link" title="Tahar Rahim">
# <img alt="Tahar Rahim" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_162_216/pictures/15/05/22/16/08/371210.jpg" height="" src="..." width=""/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/personne/fichepersonne_gen_cpersonne=171899.html">Tahar Rahim</a>
# </div>
# <div class="meta-sub light">
#           Rôle : Charles Sobhraj
#         </div>
# </div>
# </div>
# <div class="card person-card person-card-col">
# <figure class="thumbnail">
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT0yMjkzMDcuaHRtbA== thumbnail-container thumbnail-link" title="Jenna Coleman">
# <img alt="Jenna Coleman" class="thumbnail-img" data-src="https://fr.web.img4.acsta.net/c_162_216/pictures/19/06/20/12/42/0158997.jpg" height="" src="..." width=""/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/personne/fichepersonne_gen_cpersonne=229307.html">Jenna Coleman</a>
# </div>
# <div class="meta-sub light">
#           Rôle : Marie-Andrée Leclerc
#         </div>
# </div>
# </div>
# <div class="card person-card person-card-col">
# <figure class="thumbnail">
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT02ODEwNjMuaHRtbA== thumbnail-container thumbnail-link" title="Billy Howle">
# <img alt="Billy Howle" class="thumbnail-img" data-src="https://fr.web.img4.acsta.net/c_162_216/pictures/18/11/12/14/58/5263750.jpg" height="" src="..." width=""/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/personne/fichepersonne_gen_cpersonne=681063.html">Billy Howle</a>
# </div>
# <div class="meta-sub light">
#           Rôle : Herman Knippenberg
#         </div>
# </div>
# </div>
# <div class="card person-card person-card-col">
# <figure class="thumbnail">
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT03MDkxOTYuaHRtbA== thumbnail-container thumbnail-link" title="Ellie Bamber">
# <img alt="Ellie Bamber" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_162_216/pictures/19/07/02/14/31/4398029.jpg" height="" src="..." width=""/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/personne/fichepersonne_gen_cpersonne=709196.html">Ellie Bamber</a>
# </div>
# <div class="meta-sub light">
#           Rôle : Angela Knippenberg
#         </div>
# </div>
# </div>
# </div>
# <span class="ACrL3NACrlcmllcy9maWNoZXNlcmllLTI1MzYyL2Nhc3Rpbmcvc2Fpc29uLTM2NTQ1Lw== end-section-link" title="Voir le casting complet">Voir le casting complet</span>
# </section>
# <section class="section ovw">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md"><a class="titlebar-link" href="/series/ficheserie-25362/photos/">Photos</a></h2></div>
# <div class="shot-holder cf">
# <a class="shot-item shot-item-big" href="/series/ficheserie-25362/photos/detail/?cmediafile=21812223" title="Photo Jenna Coleman, Tahar Rahim">
# <img alt="Photo Jenna Coleman, Tahar Rahim" class="shot-img" data-src="https://fr.web.img5.acsta.net/c_300_300/pictures/21/03/24/20/07/2085388.jpg" height="300" src="..." width="300"/>
# </a>
# <a class="shot-item" href="/series/ficheserie-25362/photos/detail/?cmediafile=21812222" title="Photo Tahar Rahim">
# <img alt="Photo Tahar Rahim" class="shot-img" data-src="https://fr.web.img4.acsta.net/c_300_300/pictures/21/03/24/20/07/2069787.jpg" height="150" src="..." width="150"/>
# </a>
# <a class="shot-item" href="/series/ficheserie-25362/photos/detail/?cmediafile=21812221" title="Photo Tahar Rahim">
# <img alt="Photo Tahar Rahim" class="shot-img" data-src="https://fr.web.img3.acsta.net/c_300_300/pictures/21/03/24/20/07/2047946.jpg" height="150" src="..." width="150"/>
# </a>
# <a class="shot-item" href="/series/ficheserie-25362/photos/detail/?cmediafile=21812220" title="Photo Jenna Coleman, Tahar Rahim">
# <img alt="Photo Jenna Coleman, Tahar Rahim" class="shot-img" data-src="https://fr.web.img6.acsta.net/c_300_300/pictures/21/03/24/20/07/2033906.jpg" height="150" src="..." width="150"/>
# </a>
# <a class="shot-item" href="/series/ficheserie-25362/photos/detail/?cmediafile=21812219" title="Photo Jenna Coleman, Tahar Rahim">
# <img alt="Photo Jenna Coleman, Tahar Rahim" class="shot-img" data-src="https://fr.web.img2.acsta.net/c_300_300/pictures/21/03/24/20/07/2019865.jpg" height="150" src="..." width="150"/>
# </a>
# <span class="ACrL3NACrlcmllcy9maWNoZXNlcmllLTI1MzYyL3Bob3Rvcy9kZXRhaWwvP2NtZWRpYWZpbGU9MjE4MTIyMTg= shot-item" title="Photo Jenna Coleman">
# <img alt="Photo Jenna Coleman" class="shot-img" data-src="https://fr.web.img5.acsta.net/c_300_300/pictures/21/03/24/20/07/2005825.jpg" height="150" src="..." width="150"/>
# </span>
# <span class="ACrL3NACrlcmllcy9maWNoZXNlcmllLTI1MzYyL3Bob3Rvcy9kZXRhaWwvP2NtZWRpYWZpbGU9MjE4MTIyMTc= shot-item" title="Photo Amesh Edireweera, Tahar Rahim">
# <img alt="Photo Amesh Edireweera, Tahar Rahim" class="shot-img" data-src="https://fr.web.img4.acsta.net/c_300_300/pictures/21/03/24/20/07/1991784.jpg" height="150" src="..." width="150"/>
# </span>
# <span class="ACrL3NACrlcmllcy9maWNoZXNlcmllLTI1MzYyL3Bob3Rvcy9kZXRhaWwvP2NtZWRpYWZpbGU9MjE4MTIyMTY= shot-item" title="Photo Tahar Rahim">
# <img alt="Photo Tahar Rahim" class="shot-img" data-src="https://fr.web.img3.acsta.net/c_300_300/pictures/21/03/24/20/07/1977743.jpg" height="150" src="..." width="150"/>
# </span>
# <span class="ACrL3NACrlcmllcy9maWNoZXNlcmllLTI1MzYyL3Bob3Rvcy9kZXRhaWwvP2NtZWRpYWZpbGU9MjE4MTIyMTU= shot-item" title="Photo Ellie Bamber, Tahar Rahim">
# <img alt="Photo Ellie Bamber, Tahar Rahim" class="shot-img" data-src="https://fr.web.img3.acsta.net/c_300_300/pictures/21/03/24/20/07/1962143.jpg" height="150" src="..." width="150"/>
# </span>
# </div>
# <span class="ACrL3NACrlcmllcy9maWNoZXNlcmllLTI1MzYyL3Bob3Rvcy8= end-section-link" title="12 Photos">12 Photos</span>
# </section>
# <div id="mobile-referrer-mtf"></div>
# <section class="section section-ovw-video ovw">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md"><span class="ACrL3NACrlcmllcy9maWNoZXNlcmllLTI1MzYyL3ZpZGVvcy8= titlebar-link">Les dernières vidéos</span></h2></div>
# <div class="gd gd-gap-15">
# <div class="video-card-player info-hidden-on-play">
# <figure class="player js-player" data-model='{"file_name":{"high":"\/nmedia\/33\/21\/04\/08\/13\/19591843_hd_013.mp4","medium":"\/nmedia\/33\/21\/04\/08\/13\/19591843_sd_013.mp4"},"context":"seriespage","endScreen":true,"disableAutoPause":true,"launch":"scroll-play","followScroll":true,"videos":[{"id":19591843,"sources":{"medium":"\/\/fr.vid.web.acsta.net\/nmedia\/33\/21\/04\/08\/13\/19591843_sd_013.mp4","high":"\/\/fr.vid.web.acsta.net\/nmedia\/33\/21\/04\/08\/13\/19591843_hd_013.mp4"},"image":"\/videothumbnails\/21\/04\/08\/16\/15\/5993558.jpg","title":"Le Serpent sur Netflix : Tahar Rahim raconte comment il s\u2019est gliss\u00e9 dans la peau du tueur en s\u00e9rie","trackingIdentifier":"19591843-le_serpent_sur_netflix_tahar_rahim_raconte_comment_il_s_est_glisse_dans_la_peau_du_tueur_en_serie","embedUrl":"ACraHRACr0cHM6Ly9wbGF5ZXIuYWxsb2NpbmUuZnIvMTk1OTE4NDMuaHRtbA==","id_type":31007,"file_type":"interview","description":"Le Serpent sur Netflix : Tahar Rahim raconte comment il s\u2019est gliss\u00e9 dans la peau du tueur en s\u00e9rie","duration":328,"view_count":14923,"added_at":{"date":"2021-04-08 13:12:00.000000","timezone_type":3,"timezone":"Europe\/Paris"},"metas":{"genre_main_series":[{"name":"Drame","id":"13008"},{"name":"Policier","id":"13018"},{"name":"Thriller","id":"13023"},{"name":"Biopic","id":"13027"}],"id_main_person":171899,"id_main_series":25362,"id_meta_category":158006,"image_main_person":"\/pictures\/15\/05\/22\/16\/08\/371210.jpg","image_main_series":"\/pictures\/21\/03\/04\/16\/06\/5540747.jpg","localized_file_type":"interview","main_series_rating":4.0292902,"name_main_person":"Tahar Rahim","name_main_series":"Le Serpent","name_meta_category":"Stars","release_status_series":"Termin\u00e9e","trans_file_type":"Interview"},"relatedEntityType":"series","relatedEntityTrackingIdentifier":"25362-le_serpent","relatedEntityTitle":"Le Serpent","relatedEntityId":25362,"relatedEntityUrl":"ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvc2VyaWVzL2ZpY2hlc2VyaWVfZ2VuX2NzZXJpZT0yNTM2Mi5odG1s","mediaUrl":"ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvdmlkZW8vcGxheWVyX2dlbl9jbWVkaWE9MTk1OTE4NDMmY3NlcmllPTI1MzYyLmh0bWw="}],"disablePreroll":false,"disablePostroll":false}' data-thumb="https://fr.web.img5.acsta.net/r_640_360/videothumbnails/21/04/08/16/15/5993558.jpg">
# <div class="media-holder js-media-holder">
# <img alt="Le Serpent sur Netflix : Tahar Rahim raconte comment il s’est glissé dans la peau du tueur en série" class="media-cover js-media-cover" data-src="https://fr.web.img5.acsta.net/r_640_360/videothumbnails/21/04/08/16/15/5993558.jpg" height="360" src="..." width="640"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# <script type="text/javascript">
#     var wads = wads || {};
#     var wadsBeforeStartAlreadyDone = false;
#     var wadsQuery = 'route=seriespage&series=25362&genre=13008|13018|13023|13027&is_netflix=0&is_amazon=0';
#
#     function wadsBeforeStart() {
#         if (wadsBeforeStartAlreadyDone) {
#             return false;
#         }
#
#         wads.mode = 'async';
#         wads.public.setSitePage('allocine_fr/ficheserie');
#
#         // update sitepage only for mobile & tablet
#         if (window.innerWidth < 480) {
#             wads.public.setSitePage(wads.sitepage.replace('/', '_mobile/'));
#         } else if(
#             window.innerWidth < 992 ||
#             /Android|webOS|iPhone|iPad|iPod|BlackBerry|IEMobile|Opera Mini/i.test(navigator.userAgent)
#         ) {
#             wads.public.setSitePage(wads.sitepage.replace('/', '_tablet/'));
#         }
#
#         wads.callBaseUrlAutopromo = 'http://autopromo.allocine.fr';
#         wads.cookieBaseUrlAutopromo = 'http://autopromo.allocine.fr';
#         wads.callBaseUrlAcceptable = 'http://acceptable.allocine.fr';
#         wads.cookieBaseUrlAcceptable = 'http://acceptable.allocine.fr';
#
#         wadsBeforeStartAlreadyDone = true;
#     }
# </script>
# <div class="media-player-holder">
# <div class="js-media-player"></div>
# </div>
# </div>
# </figure>
# <div class="player-info">
# <div class="item">
# <a class="item-link" href="/personne/fichepersonne-171899/interviews/?cmedia=19591843">Le Serpent sur Netflix : Tahar Rahim raconte comment il s’est glissé dans la peau du tueur en série</a>
# </div>
# </div>
# </div>
# </div>
# <div class="gd gd-gap-15 gd-xs-1 gd-s-3">
# <div class="card video-card video-card-col">
# <figure class="thumbnail">
# <div class="thumbnail-container">
# <img alt="Le Serpent - saison 1 Bande-annonce VF" class="thumbnail-img" data-src="https://fr.web.img2.acsta.net/c_208_117/videothumbnails/21/03/04/15/51/2093594.jpg" height="117" src="..." width="208"/>
# <span class="thumbnail-count">2:01</span>
# </div>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTkxNTMyJmNzZXJpZT0yNTM2Mi5odG1s meta-title-link">Le Serpent - saison 1 Bande-annonce VF</span>
# </div>
# <div class="meta-sub light">
# <span>57500  vues</span>
# </div>
# </div>
# </div>
# <div class="card video-card video-card-col">
# <figure class="thumbnail">
# <div class="thumbnail-container">
# <img alt="The Serpent - saison 1 Teaser VO" class="thumbnail-img" data-src="https://fr.web.img3.acsta.net/c_208_117/videothumbnails/20/12/21/10/27/3841300.jpg" height="117" src="..." width="208"/>
# <span class="thumbnail-count">0:59</span>
# </div>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTkwOTUzJmNzZXJpZT0yNTM2Mi5odG1s meta-title-link">The Serpent - saison 1 Teaser VO</span>
# </div>
# <div class="meta-sub light">
# <span>4116  vues</span>
# </div>
# </div>
# </div>
# </div>
# </section>
# <div id="mobile-referrer-promo-1"></div>
# <section class="section ovw">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md"><a class="titlebar-link" href="/series/ficheserie-25362/news/">Dernières news</a></h2></div>
# <div class="hred">
# <div class="card news-card news-card-full cf"><figure class="thumbnail"><span class="ACrL2FACrydGljbGUvZmljaGVhcnRpY2xlX2dlbl9jYXJ0aWNsZT0xODY5ODUwOS5odG1s thumbnail-container thumbnail-link" title="Le Serpent sur Netflix : Tahar Rahim raconte comment il s’est glissé dans la peau du tueur en série"><img alt="Le Serpent sur Netflix : Tahar Rahim raconte comment il s’est glissé dans la peau du tueur en série" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_640_360/newsv7/21/04/08/16/38/0966137.jpg" height="360" src="..." width="640"/></span></figure><div class="meta"><div class="meta-category">NEWS - Séries à la TV</div><div class="meta-date">jeudi 8 avril 2021</div><h3 class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=18698509.html">Le Serpent sur Netflix : Tahar Rahim raconte comment il s’est glissé dans la peau du tueur en série</a></h3></div></div> </div>
# <div class="hred">
# <div class="card news-card news-card-row cf"><figure class="thumbnail"><div class="thumbnail-container"><img alt="Le Serpent sur Netflix : comment une petite ville d’Angleterre a servi de décor pour la Thaïlande" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_400_225/newsv7/21/04/07/18/08/3006373.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NEWS - Séries à la TV</div><div class="meta-date">mercredi 7 avril 2021</div><h3 class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=18698471.html">Le Serpent sur Netflix : comment une petite ville d’Angleterre a servi de décor pour la Thaïlande</a></h3><div class="meta-body">Dans Le Serpent, disponible sur Netflix, les spectateurs voyagent dans l'Asie des années 1970. Comme de nombreux tournages,...</div></div></div> </div>
# <div class="hred">
# <div class="card news-card news-card-row cf"><figure class="thumbnail"><div class="thumbnail-container"><img alt="Netflix : 5 séries à ne pas rater ce printemps  " class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_400_225/newsv7/21/04/06/16/33/5270850.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NEWS - Séries à la TV</div><div class="meta-date">mardi 6 avril 2021</div><h3 class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=18698404.html">Netflix : 5 séries à ne pas rater ce printemps  </a></h3><div class="meta-body">Le printemps est là mais il fait un temps à rester chez soi et à binge-watcher des séries. Voilà d'ailleurs celles qu'il...</div></div></div> </div>
# <div class="hred">
# <div class="card news-card news-card-row cf"><figure class="thumbnail"><div class="thumbnail-container"><img alt="Le Serpent sur Netflix : que vaut ce thriller glaçant avec Tahar Rahim ?" class="thumbnail-img" data-src="https://fr.web.img5.acsta.net/c_400_225/newsv7/21/04/01/17/33/5632928.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NEWS - Séries à la TV</div><div class="meta-date">vendredi 2 avril 2021</div><h3 class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=18698346.html">Le Serpent sur Netflix : que vaut ce thriller glaçant avec Tahar Rahim ?</a></h3><div class="meta-body">Disponible sur Netflix, cette mini-série met en scène le tueur en série Charles Sobhraj incarné par Tahar Rahim. Ce faux...</div></div></div> </div>
# <div class="hred">
# <div class="card news-card news-card-row cf"><figure class="thumbnail"><div class="thumbnail-container"><img alt="Netflix : quelles sont les séries à voir en avril 2021 ?" class="thumbnail-img" data-src="https://fr.web.img2.acsta.net/c_400_225/newsv7/21/03/26/15/59/5330597.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NEWS - Séries à la TV</div><div class="meta-date">mercredi 31 mars 2021</div><h3 class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=18698145.html">Netflix : quelles sont les séries à voir en avril 2021 ?</a></h3><div class="meta-body">AlloCiné vous dit quelles séries arrivent sur Netflix en avril. À vos agendas !
# </div></div></div> </div>
# <span class="ACrL3NACrlcmllcy9maWNoZXNlcmllLTI1MzYyL25ld3Mv end-section-link" title="7 news sur cette série">7 news sur cette série</span>
# </section>
# <section class="section ovw">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md"><span class="ACrL3NACrlcmllcy9maWNoZXNlcmllLTI1MzYyL2NyaXRpcXVlcy8= titlebar-link">Critiques Spectateurs</span></h2></div>
# <div class="hred review-card cf" id="review_1014099059">
# <div class="review-card-aside">
# <div class="review-card-user-infos cf">
# <figure class="thumbnail">
# <span class="ACrL21ACrlbWJyZS1aMjAxNjAxMTQxNzU0MDYyMTcyMTc2NTYv thumbnail-container thumbnail-link" title="Farid B.">
# <img alt="Farid B." class="thumbnail-img" data-src="https://graph.facebook.com/1553373138319749/picture?width=80&amp;height=80" height="80" src="..." width="80"/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <span class="ACrL21ACrlbWJyZS1aMjAxNjAxMTQxNzU0MDYyMTcyMTc2NTYv">Farid B.</span>
# </div>
# <p class="meta-content light">
# <span class="item-profil js-follow-unfollow" data-targetuserid="Z20160114175406217217656" data-totalreviews="5">
#                     Suivre son activité
#                 </span>
# ...
# <!-- DIDOMI GLOBALS -->
# <script type="text/javascript">
#     window.didomiOnReady = window.didomiOnReady || [];
#     window.didomiEventListeners = window.didomiEventListeners || [];
# </script>
# <!-- DIDOMI CMP SCRIPT WITH PAYWAL -->
# <script type="text/javascript">window.gdprAppliesGlobally=true;(function(){function a(e){if(!window.frames[e]){if(document.body&&document.body.firstChild){var t=document.body;var n=document.createElement("iframe");n.style.display="none";n.name=e;n.title=e;t.insertBefore(n,t.firstChild)}
#     else{setTimeout(function(){a(e)},5)}}}function e(n,r,o,c,s){function e(e,t,n,a){if(typeof n!=="function"){return}if(!window[r]){window[r]=[]}var i=false;if(s){i=s(e,t,n)}if(!i){window[r].push({command:e,parameter:t,callback:n,version:a})}}e.stub=true;function t(a){if(!window[n]||window[n].stub!==true){return}if(!a.data){return}
#     var i=typeof a.data==="string";var e;try{e=i?JSON.parse(a.data):a.data}catch(t){return}if(e[o]){var r=e[o];window[n](r.command,r.parameter,function(e,t){var n={};n[c]={returnValue:e,success:t,callId:r.callId};a.source.postMessage(i?JSON.stringify(n):n,"*")},r.version)}}
#     if(typeof window[n]!=="function"){window[n]=e;if(window.addEventListener){window.addEventListener("message",t,false)}else{window.attachEvent("onmessage",t)}}}e("__tcfapi","__tcfapiBuffer","__tcfapiCall","__tcfapiReturn");a("__tcfapiLocator");(function(e){
#     var t=document.createElement("script");t.id="spcloader";t.type="text/javascript";t.async=true;t.src="https://sdk.privacy-center.org/"+e+"/loader.js?target_type=notice&target=TtwHt2xD";t.charset="utf-8";var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(t,n)})('e23a01f6-a508-4e71-8f50-c1a9cae7c0d0')})();</script>
# <!-- DIDOMI CMP SCRIPT ENDS -->
# <script type="text/javascript">
#             var dataLayerGA = {"dimension10":"seriespage","dimension9":"no","dimension24":5004,"dimension25":122006,"dimension26":"13008","dimension27":"13018","dimension62":"bbc_one","dimension64":"","dimension70":"no","dimension76":"null","dimension79":null,"dimension82":"25362-le_serpent","dimension83":"production_ended","dimension84":"series","dimension87":25362,"dimension92":"netflix","dimension93":"netflix_original","metric2":7,"metric3":0,"metric10":1};
#         </script>
# <script type="text/javascript">
#         var JadConfig = {"provider":"dfp","system":"jad","account-id":"\/120157152","account-first-level":"\/ALLOCINE_FR_WEB","tag-id":"\/120157152\/ALLOCINE_FR_WEB","tag-other-levels":"\/seriespage\/seriespage","navEgg":null,"targeting":{"site":"allocine","site_route":"seriespage","site_section":"seriespage","environment":"web","series_id":"25362","series_label":"le_serpent","genre":["13008","13018","13023","13027"],"production_status":"terminee","is_netflix":"1","is_amazon":"0","is_disney":"0","is_mycanal":"0","is_svod_originals":"1","is_svod_exclusive":"0","svod_providers":["netflix"],"countries":["United Kingdom","USA"]},"autoRefresh":true,"cmpPaywall":{"name":"didomi","siteId":"e23a01f6-a508-4e71-8f50-c1a9cae7c0d0","noticeId":"TtwHt2xD","paywall":{"clientId":"AVvF60FpOZcS6UoBe6sf8isBLYwzuLgMQCnNdE-FvpoW_OhR8P6zERqhyuIBGPOxqrTHKxv7QxsXnfck","planId":"P-66F73522PX986223DMBQZG5A","tosUrl":"\/service\/cgv.html","touUrl":"\/service\/conditions.html","privacyUrl":"\/service\/charte.html"},"includeCmp":false}};
#         var JadIds    = ["dfp-interstitial","dfp-headerlink","dfp-masthead","dfp-nativebanner","dfp-nativerectangle","dfp-nativevod","dfp-atf","dfp-atf","dfp-mtf","dfp-mtf","dfp-autopromo","dfp-btf","dfp-btf","dfp-pulse"];
#     </script>
# <script type="text/javascript">(function (win) {
#     win.AC = win.AC || {};
#     AC.config = {"releaseWeekDay":"Wednesday","locale":"fr_FR","lang":"fr","brand":"allocine","siteKey":"fr","graphCountryName":"FRANCE","display_provider":"jad","asset_version":"74fb277f66ad82743977326fcd462d143b110a75","env":"prod","assetsUrls":{"css":{"secondary":"https:\/\/assets.allocine.fr\/skin\/css\/allocine\/secondary-styles.min-e23f914690.css","font":"https:\/\/assets.allocine.fr\/skin\/css\/allocine\/font.min-c4d149dbf5.css"},"images":{"logo":"https:\/\/assets.allocine.fr\/skin\/img\/logo-allocine-287bbe0668.svg","bronson":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/bronson-e492ec8e56.gif","seriously":"https:\/\/assets.allocine.fr\/skin\/img\/seriously-ffccba6479.gif","walle":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/walle-5d973cbbc2.png","notFound":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/not-found-dec1f46fbc.gif","ghostBuster":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/ghostbuster-7c731e1347.png","etoile":"https:\/\/assets.allocine.fr\/skin\/img\/etoiles-766780d2bf.png","onboarding":"https:\/\/assets.allocine.fr\/skin\/img\/allocine\/onboarding-a32c4541a1.png","suggestions":"https:\/\/assets.allocine.fr\/skin\/img\/suggestions-0009180ea0.png","macaron":"https:\/\/assets.allocine.fr\/skin\/img\/macaron-363298eee7.png"}},"webedia_websites":["allocine.fr","www.academiedugout.fr","www.canalblog.com","www.over-blog.com","www.confidentielles.com","www.750g.com","www.alibabuy.com","www.chartsinfrance.net","www.dailyconso.com","www.easyvols.fr","www.easyvoyage.com","www.exponaute.com","www.forumjv.com","fr.ign.com","jeu.info","www.jeuxvideo.com","www.lebonguide.com","www.lofficielmode.com","www.millenium.org","www.purebreak.com","www.purecine.com","www.purefamille.com","www.purfans.com","www.pureloisirs.com","www.ozap.com","www.purepeople.com","www.puresaveurs.com","www.shopoon.fr","www.puresweethome.com","www.puretrend.com","www.terrafemina.com","www.yasmina.com","www.atyabtabkha.3a2ilati.com","www.3a2ilati.com","www.mashaheeri.com","www.mazyun.com","www.beyazperde.com","www.filmstarts.de","www.moviepilot.de","www.gamestar.de","www.onlinewelten.com","de.ign.com","www.gamespilot.de","www.heimgourmet.com","www.easyvoyage.de","www.adorocinema.com","br.ign.com","www.purepeople.com.br","www.purebreak.com.br","www.pureviagem.com.br","www.tudogostoso.com.br","www.receitas-sem-fronteiras.com","www.easyvoyage.co.uk","www.dealchecker.co.uk","www.gourmandize.com","www.sensacine.com","www.3djuegos.com","es.ign.com","www.easyviajar.com","www.rebanando.com","www.easyviaggio.com","www.tribugolosa.com"],"hosts":{"assets":"https:\/\/assets.allocine.fr","secure":"https:\/\/secure.allocine.fr","secureApi":"https:\/\/api-secure.allocine.fr","validation":"https:\/\/secure.allocine.fr","sso":"https:\/\/sso.allocine.fr","graph":"https:\/\/graph.allocine.fr","hostname":"allocine.fr"},"ads":{"displayProvider":"jad","prerollProvider":"jad","postrollProvider":"wads","postrollProxy":"\/\/videos.allocine.fr","atf":"atf","slideshow":"slideshow","slideshownativebanner":"slideshownativebanner","positions":"dfp-atf,dfp-mtf,dfp-btf,dfp-interstitial,dfp-masthead,,dfp-slideshow,dfp-slideshownativebanner,dfp-sticky-amp,,,dfp-inread,,,,dfp-headerlink,,dfp-autopromo,dfp-pulse,dfp-nativebanner,dfp-nativebanner-ope,dfp-nativerectangle,dfp-nativebutton,dfp-nativevod,"},"secureApiPartnerKey":"000042532791","facebook":{"appId":"99197768694","version":"v3.2","permissions":"public_profile email user_friends"},"google":{"appId":"472230823030.apps.googleusercontent.com","apiKey":"pxKT_spGOdGnt7MVJXcTGCGr","permissions":"https:\/\/www.googleapis.com\/auth\/userinfo.email https:\/\/www.googleapis.com\/auth\/plus.login","tagManagerId":"GTM-PL6PBF","analyticsUACode":"UA-597605-13","analyticsPartners":[],"reCaptchaSiteKey":"6Les8ukZAAAAACSRJMDHQqUcD2iwl1wGq1or2g4S"},"disqus":{"shortname":"allocine-prod2","apiKey":"WmFI6FIX8lZxK1fZdaYuGxizFUoFfJn3iCHfRulxsPNMQOfZwDWbnD0xyjS6fqSR","ssoButton":"https:\/\/fr.web.img1.acsta.net\/commons ...
#     AC.routing = {"base_url":"","routes":{"allocine__moviepage":{"tokens":[["text",".html"],["variable","=","[1-9]\\d*","movie"],["text","\/film\/fichefilm_gen_cfilm"]],"defaults":[],"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes":{"tokens":[["text","\/"],["variable","-","[1-9]\\d*","movie"],["text","\/seance\/film"]],"defaults":[],"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_place":{"tokens":[["part","__urlpart0__",[["text","\/"],["variable","-","[0-9]{1,2}","day"],["text","d"]]],["text","\/"],["variable","-","\\d+","localization"],["text","\/pres-de"],["variable","-","[1-9]\\d*","movie"],["text","\/seance\/film"]],"defaults":{"day":0},"requirements":{"localization":"\\d+","day":"[0-9]{1,2}","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_my_theaters":{"tokens":[["part","__urlpart0__",[["text","\/"],["variable","-","[0-9]{1,2}","day"],["text","d"]]],["text","\/favoris\/seances\/"],["variable","-","[1-9]\\d*","movie"],["text","\/seance\/film"]],"defaults":{"day":0},"requirements":{"day":"[0-9]{1,2}","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_lookup":{"tokens":[["text","\/recherche\/"],["variable","-","[1-9]\\d*","movie"],["text","\/seance\/film"]],"defaults":[],"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_videos_trailer":{"tokens":[["text",".html"],["variable","=","[1-9]\\d*","movie"],["text","&cfilm"],["variable","=","[1-9]\\d*","idMedia"],["text","\/video\/player_gen_cmedia"]],"defaults":[],"requirements":{"idMedia":"[1-9]\\d*","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_all_videos_trailer":{"tokens":[["text","\/toutes\/"],["variable","-","[1-9]\\d*","movie"],["text","\/videos\/fichefilm"]],"defaults":[],"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_casting":{"tokens":[["text","\/casting\/"],["variable","-","[1-9]\\d*","movie"],["text","\/film\/fichefilm"]],"defaults":[],"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_reviews_press":{"tokens":[["text","\/critiques\/presse\/"],["variable","-","[1-9]\\d*","movie"],["text","\/film\/fichefilm"]],"defaults":[],"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_reviews_public":{"tokens":[["part","__urlpart0__",[["text","\/"],["variable","-","[0-5]","starsFilter"],["text","star"]]],["text","\/critiques\/spectateurs\/"],["variable","-","[1-9]\\d*","movie"],["text","\/film\/fichefilm"]],"defaults":[],"requirements":{"starsFilter":"[0-5]","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_reviews_public_recent":{"tokens":[["part","__urlpart0__",[["text","\/"],["variable","-","[0-5]","starsFilter"],["text","star"]]],["text","\/critiques\/spectateurs\/recentes\/"],["variable","-","[1-9]\\d*","movie"],["text","\/film\/fichefilm"]],"defaults":[],"requirements":{"starsFilter":"[0-5]","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_reviews_public_membres":{"tokens":[["part","__urlpart0__",[["text","\/"],["variable","-","[0-5]","starsFilter"],["text","star"]]],["text","\/critiques\/spectateurs\/membres-critiques\/"],["variable","-","[1-9]\\d*","movie"],["text","\/film\/fichefilm"]],"defaults":[],"requirements":{"starsFilter":"[0-5]","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"], ...
#     AC.route = 'seriespage';
# }(window));</script>
# <script src="https://assets.allocine.fr/js/website/translations-d5a26019c76322d72d12d32f753ec747.fr_FR.js"></script>
# <script src="https://assets.allocine.fr/js/website/website-common.f0d2a680761eb6e8289d.js" type="text/javascript"></script>
# <script defer="" src="https://assets.allocine.fr/js/website/seriespage.4e98b7c6928ae539bd99.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var dataLayer = dataLayer || [{"site_route":"seriespage","site_section":"seriespage","series_id":25362,"series_label":"le_serpent","series_distributors":"","series_releaser":[],"is_netflix":1,"is_amazon":0,"is_disney":0,"is_mycanal":0,"is_svod_originals":1,"is_svod_exclusive":0,"tags":[],"svod_providers":["netflix"],"countries":["United Kingdom","USA"]}];
# </script>
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-PL6PBF" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script type="text/javascript">
#             var asyncDataLayers = [];
#             var jsEntities = {"U2Vhc29uOjM2NTQ1":{"id":"U2Vhc29uOjM2NTQ1","number":1,"season_status":122006},"U2VyaWVzOjI1MzYy":{"id":"U2VyaWVzOjI1MzYy","title":"Le Serpent","flags":{"isComingSoon":false},"releaseDate":"2021-01-01T00:00:00+01:00","broadcasted_seasons":["U2Vhc29uOjM2NTQ1"]}};
#         </script>
# <script type="application/ld+json">
# {
#     "@context":"http://schema.org",
#     "@type":"TVSeries",
#     "name":"Le Serpent",
#     "image":"https://fr.web.img5.acsta.net/pictures/21/03/04/16/06/5540747.jpg",
#     "numberOfEpisodes":"8",
#     "numberOfSeasons":"1"
#         ,
#     "genre": [
#             "Drame",
#                 "Policier",
#                 "Thriller",
#                 "Biopic"
#             ]
#             ,
#     "description": "L'histoire de l’escroc Charles Sobhraj et les tentatives remarquables du diplomate néerlandais Herman Knippenberg pour le traduire en justice. Se faisant passer pour un négociant en pierres précieuses, Charles Sobhraj et sa compagne Marie-Andrée Leclerc voyagent à travers la Thaïlande, le Népal et l’Inde entre 1975 et 1976, commettant sur leur passage une série de crimes sur le « Hippie Trail» asiatique."
#             ,
#     "aggregateRating": {
#         "@type": "AggregateRating",
#         "ratingValue": "4,0",
#         "ratingCount": "439",
#                 "reviewCount": "79",
#                 "bestRating": "5",
#         "worstRating": "0,5"
#     }
#     }
# </script>
# <script>
#     (function(win, undefined) {
#         var tests = [];
#
#         // add tests here
#         tests.push(function() {
#             return 'CSS' in win && CSS.supports('display', 'grid');
#         });
#
#         // run all tests
#         var length = tests.length;
#         var idx = 0;
#         var supported = true;
#
#         for (idx = 0; supported && idx < length; idx += 1) {
#             supported = tests[idx]();
#         }
#
#         // display banner
#         if (!supported) {
#             var doc = win.document;
#             var alertBanner = doc.createElement('div');
#             var alertContent = alertBanner.cloneNode('div'); // performence best pratice
#             var bannerText = doc.createTextNode("La version de votre navigateur n'est plus supportée, l'expérience sur le site sera dégradée. Si vous ne pouvez ni mettre à jour votre navigateur, ni en changer, sachez que le site est consultable sur mobile à la même adresse.");
#
#             alertBanner.className = "alert-deprecated-banner alert-info";
#             alertContent.className = "alert-content";
#
#             var body = doc.body;
#             var head = doc.getElementsByTagName('head')[0];
#
#             var header = doc.getElementById('main-header');
#             var link = doc.createElement('link');
#
#             alertContent.appendChild(bannerText);
#             alertBanner.appendChild(alertContent);
#
#             body.insertBefore(alertBanner, header || body.firstChild);
#             body.className += ' deprecated';
#
#             // @todo css deprecated
#             link.setAttribute('href', 'https\u003A\/\/assets.allocine.fr\/skin\/css\/allocine\/deprecated.min\u002D554090a2ab.css');
#             link.setAttribute('rel', 'stylesheet');
#             link.setAttribute('type', 'text/css');
#             head.appendChild(link);
#         }
#     })(window);
# </script>
# </div>
# </body>
# <!-- cTime 15:59:15 -->
# </html>

# %% [markdown]
# For title
# ```html
# <div class="titlebar-title titlebar-title-lg">Le Grand Bain</div>
# ```
# For the synopsis
#
# ```html
# <div class="content-txt " itemprop="description"
#
#
#               C’est dans les couloirs de leur piscine municipale que Bertrand, Marcus, Simon, Laurent, Thierry et les autres s’entraînent sous l’autorité toute relative de Delphine, ancienne gloire des bassins. Ensemble, ils se sentent libres et utiles. Ils vont mettre toute leur énergie dans une discipline jusque-là propriété de la gent féminine : la natation synchronisée. Alors, oui c’est une idée plutôt bizarre, mais ce défi leur permettra de trouver un sens à leur vie...
#
#       </div>
# ```

# %%
for elem in soup.find_all('div',attrs={"class" :"titlebar-title titlebar-title-lg"}):
    # Just like that
    print(elem.text)
    
for elem in soup.find_all('div',attrs={"class" :"content-txt "}):
    # Just like that
    print(elem.text)
# Out:
# Le Serpent

# %% [markdown]
# 1) Automate this script for the entire list
#
# 2) Put the information in three lists (film_links, title, synopsis)
#
# 3) Create a dataframe that includes these three informations in three associated columns
#
# 4) Save this dataframe in a csv file
#
# And here's your first real scrap, you're real hackers now.

# %%
import time
import random
from random import randint

title=[]
synopsis=[]

for link in links_movie:
    
    url=link
    # I slow down the frequency of requests to avoid being identified and therefore ban from the site
    time.sleep(random.uniform(1.0, 2.0))
    r = requests.get(url)
    print(url, r.status_code)
    soup = BeautifulSoup(r.content,'lxml')
    
    
    for elem in soup.find_all('div',attrs={"class" :"titlebar-title titlebar-title-lg"}):
        title.append(elem.text.strip())

    for elem in soup.find_all('div',attrs={"class" :"content-txt"}):
        synopsis.append(elem.text.strip())
        
# I check the length of the lists before creating the df
len(title),len(synopsis),len(links_movie)
# Out:
# http://www.allocine.fr/series/ficheserie_gen_cserie=25362.html 200
# http://www.allocine.fr/series/ficheserie_gen_cserie=27414.html 200
# http://www.allocine.fr/series/ficheserie_gen_cserie=28562.html 200
# http://www.allocine.fr/series/ficheserie_gen_cserie=27142.html 200
# http://www.allocine.fr/series/ficheserie_gen_cserie=23853.html 200
# http://www.allocine.fr/series/ficheserie_gen_cserie=25616.html 200
# http://www.allocine.fr/series/ficheserie_gen_cserie=24647.html 200
# (7, 23, 7)

# %%
import pandas as pd
df=pd.DataFrame({'Titre':title})
df['synopsis']=synopsis[0:7]
df['liens']=links_movie

# %%
df.to_csv('./assets/allo_cine.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-46-fd3619aceaf1> in <module>
# ----> 1 df.to_csv('./assets/allo_cine.csv', index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3401             doublequote=doublequote,
#    3402             escapechar=escapechar,
# -> 3403             storage_options=storage_options,
#    3404         )
#    3405
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     232             errors=self.errors,
#     233             compression=self.compression,
# --> 234             storage_options=self.storage_options,
#     235         ) as handles:
#     236
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     645                 encoding=ioargs.encoding,
#     646                 errors=errors,
# --> 647                 newline="",
#     648             )
#     649         else:
#
# PermissionError: [Errno 13] Permission denied: './assets/allo_cine.csv'
