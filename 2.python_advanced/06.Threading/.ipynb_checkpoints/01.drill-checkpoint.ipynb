# %% [markdown]
# # Drill - Threading

# %% [markdown]
# ### Exercise 1
# In the `data/` folder, you have 10 files that contain Shakespears sonnets. You have to gather all these files into one file `data_all.txt` using threads. Be careful, the sonnets must appear in order.

# %%
import os
from threading import Thread, RLock

class ThreadSonnet(Thread):
    def __init__(self, name):
        Thread.__init__(self)
        self.name = "data/"+name
        
    def run(self):
        with lock:
            text=""
            with open(self.name, "r") as f:
                text=f.read()
            with open("data/data_all.txt", "a")as f:
                f.write(text)

lock = RLock()
files = os.listdir("./data/")
print(files)
for f in files:
    thread = ThreadSonnet(f)
    thread.start()
# Out:
# ['data_part_1.txt', 'data_part_10.txt', 'data_part_2.txt', 'data_part_3.txt', 'data_part_4.txt', 'data_part_5.txt', 'data_part_6.txt', 'data_part_7.txt', 'data_part_8.txt', 'data_part_9.txt']
# Exception in thread data/data_part_1.txt:
# Traceback (most recent call last):
#   File "C:\Users\jeremy\Anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-1-f2a7c25ab3d0>", line 14, in run
#     with open("data/data_all.txt", "a")as f:
# PermissionError: [Errno 13] Permission denied: 'data/data_all.txt'
#
# Exception in thread data/data_part_2.txt:
# Traceback (most recent call last):
#   File "C:\Users\jeremy\Anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-1-f2a7c25ab3d0>", line 14, in run
#     with open("data/data_all.txt", "a")as f:
# PermissionError: [Errno 13] Permission denied: 'data/data_all.txt'
# Exception in thread data/data_part_10.txt:
# Traceback (most recent call last):
#   File "C:\Users\jeremy\Anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-1-f2a7c25ab3d0>", line 14, in run
#     with open("data/data_all.txt", "a")as f:
# PermissionError: [Errno 13] Permission denied: 'data/data_all.txt'
#
#
# Exception in thread data/data_part_3.txt:
# Traceback (most recent call last):
#   File "C:\Users\jeremy\Anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-1-f2a7c25ab3d0>", line 14, in run
#     with open("data/data_all.txt", "a")as f:
# PermissionError: [Errno 13] Permission denied: 'data/data_all.txt'
#
# Exception in thread data/data_part_4.txt:
# Traceback (most recent call last):
#   File "C:\Users\jeremy\Anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-1-f2a7c25ab3d0>", line 14, in run
#     with open("data/data_all.txt", "a")as f:
# PermissionError: [Errno 13] Permission denied: 'data/data_all.txt'
#
# Exception in thread data/data_part_5.txt:
# Traceback (most recent call last):
#   File "C:\Users\jeremy\Anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-1-f2a7c25ab3d0>", line 14, in run
#     with open("data/data_all.txt", "a")as f:
# PermissionError: [Errno 13] Permission denied: 'data/data_all.txt'
#
# Exception in thread data/data_part_6.txt:
# Traceback (most recent call last):
#   File "C:\Users\jeremy\Anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-1-f2a7c25ab3d0>", line 14, in run
#     with open("data/data_all.txt", "a")as f:
# PermissionError: [Errno 13] Permission denied: 'data/data_all.txt'
#
# Exception in thread data/data_part_7.txt:
# Traceback (most recent call last):
#   File "C:\Users\jeremy\Anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-1-f2a7c25ab3d0>", line 14, in run
#     with open("data/data_all.txt", "a")as f:
# PermissionError: [Errno 13] Permission denied: 'data/data_all.txt'
#
# Exception in thread data/data_part_8.txt:
# Traceback (most recent call last):
#   File "C:\Users\jeremy\Anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-1-f2a7c25ab3d0>", line 14, in run
#     with open("data/data_all.txt", "a")as f:
# PermissionError: [Errno 13] Permission denied: 'data/data_all.txt'
#
# Exception in thread data/data_part_9.txt:
# Traceback (most recent call last):
#   File "C:\Users\jeremy\Anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-1-f2a7c25ab3d0>", line 14, in run
#     with open("data/data_all.txt", "a")as f:
# PermissionError: [Errno 13] Permission denied: 'data/data_all.txt'

# %% [markdown]
# ### Exercise 2
# Scrap all the web pages in the urls list and display the links. 1 thread per link.

# %%
urls = [
  'http://www.python.org',
  'http://www.python.org/about/',
  'http://www.onlamp.com/pub/a/python/2003/04/17/metaclasses.html',
  'http://www.python.org/doc/',
  'http://www.python.org/download/',
  'http://www.python.org/getit/',
  'http://www.python.org/community/',
  'https://wiki.python.org/moin/',
]

# %%
from bs4 import BeautifulSoup
import requests

class ThreadURL(Thread):
    def __init__(self, url):
        Thread.__init__(self)
        self.url = url
    
    def run(self):
        r = requests.get(self.url)
        soup = BeautifulSoup(r.content,'lxml')
        for p in soup.find_all('a'):
            print (p.text)
for url in urls:
    thread1 = ThreadURL(url)
    thread1.start()
# Out:
# Skip to content
#
# ▼ Close
#
# Python
# PSF
# Docs
# PyPI
# Jobs
# Community
#
# ▲ The Python Network
#
#
# Donate
# ≡ Menu
# A A
# Smaller
# Larger
# Reset
# Socialize
# Facebook
# Twitter
# Chat on IRC
# About
# Applications
# Quotes
# Getting Started
# Help
# Python Brochure
# Downloads
# All releases
# Source code
# Windows
# Mac OS X
# Other Platforms
# License
# Alternative Implementations
# Documentation
# Docs
# Audio/Visual Talks
# Beginner's Guide
# Developer's Guide
# FAQ
# Non-English Docs
# PEP Index
# Python Books
# Python Essays
# Community
# Community Survey
# Diversity
# Mailing Lists
# IRC
# Forums
# PSF Annual Impact Report
# Python Conferences
# Special Interest Groups
# Python Logo
# Python Wiki
# Merchandise
# Community Awards
# Code of Conduct
# Get Involved
# Shared Stories
# Success Stories
# Arts
# Business
# Education
# Engineering
# Government
# Scientific
# Software Development
# News
# Python News
# PSF Newsletter
# Community News
# PSF News
# PyCon News
# Events
# Python Events
# User Group Events
# Python Events Archive
# User Group Events Archive
# Submit an Event
# Python Docs
# Documentation Releases by Version
# Beginner’s Guide
# Python FAQs
# Python Periodicals
# Python Books
# Python Packaging User Guide
# In-development Docs
# Guido’s Essays
# PEP Index
# Python Videos
# Developer’s Guide
# Browse Python 3.9.4 Documentation
# (Module Index)
# What's new in Python 3.9
# Tutorial
# Library Reference
# Language Reference
# Extending and Embedding
# Python/C API
# Using Python
# Python HOWTOs
# Glossary
# Search the online docs
# Download Current Documentation
# FAQ: Sunsetting Python 2
# Final Python 2.7 Release Schedule
# Python 3 Statement
# Porting Python 2 Code to Python 3
# Determine what projects are blocking you from porting to Python 3
# Python 2 Support and Migration
# Try our comprehensive Help section
# Python Needs You
# Learn more
# Contribute to Python
# Bug Tracker
# Python Enhancement Proposals (PEPs)
#  RSS
# ▲ Back to Top
# About
# Applications
# Quotes
# Getting Started
# Help
# Python Brochure
# Downloads
# All releases
# Source code
# Windows
# Mac OS X
# Other Platforms
# License
# Alternative Implementations
# Documentation
# Docs
# Audio/Visual Talks
# Beginner's Guide
# Developer's Guide
# FAQ
# Non-English Docs
# PEP Index
# Python Books
# Python Essays
# Community
# Community Survey
# Diversity
# Mailing Lists
# IRC
# Forums
# PSF Annual Impact Report
# Python Conferences
# Special Interest Groups
# Python Logo
# Python Wiki
# Merchandise
# Community Awards
# Code of Conduct
# Get Involved
# Shared Stories
# Success Stories
# Arts
# Business
# Education
# Engineering
# Government
# Scientific
# Software Development
# News
# Python News
# PSF Newsletter
# Community News
# PSF News
# PyCon News
# Events
# Python Events
# User Group Events
# Python Events Archive
# User Group Events Archive
# Submit an Event
# Contributing
# Developer's Guide
# Issue Tracker
# python-dev list
# Core Mentorship
# Report a Security Issue
# ▲ Back to Top
# Help & General Contact
# Diversity Initiatives
# Submit Website Bug
# Status
# Python Software Foundation
# Legal Statements
# Privacy Policy
# Powered by Heroku
# Skip to content
#
# ▼ Close
#
# Python
# PSF
# Docs
# PyPI
# Jobs
# Community
#
# ▲ The Python Network
#
#
# Donate
# ≡ Menu
# A A
# Smaller
# Larger
# Reset
# Socialize
# Facebook
# Twitter
# Chat on IRC
# About
# Applications
# Quotes
# Getting Started
# Help
# Python Brochure
# Downloads
# All releases
# Source code
# Windows
# Mac OS X
# Other Platforms
# License
# Alternative Implementations
# Documentation
# Docs
# Audio/Visual Talks
# Beginner's Guide
# Developer's Guide
# FAQ
# Non-English Docs
# PEP Index
# Python Books
# Python Essays
# Community
# Community Survey
# Diversity
# Mailing Lists
# IRC
# Forums
# PSF Annual Impact Report
# Python Conferences
# Special Interest Groups
# Python Logo
# Python Wiki
# Merchandise
# Community Awards
# Code of Conduct
# Get Involved
# Shared Stories
# Success Stories
# Arts
# Business
# Education
# Engineering
# Government
# Scientific
# Software Development
# News
# Python News
# PSF Newsletter
# Community News
# PSF News
# PyCon News
# Events
# Python Events
# User Group Events
# Python Events Archive
# User Group Events Archive
# Submit an Event
# Beginner's Guide, Programmers
# Beginner's Guide, Non-Programmers
# Beginner's Guide, Download & Installation
# Code sample and snippets for Beginners
# Conferences and Workshops
# Python Documentation
#
# IRC channels
# Python Package Index (PyPI)
# Web and Internet Development
# Database Access
# Desktop GUIs
# Scientific & Numeric
# Education
# Network Programming
# Software & Game Development
# Python Software Foundation
# Learn more about the license
# Python license on OSI
# Learn more about the Foundation
# Try our comprehensive Help section
# More
# The PSF is hiring a Python Packaging Project Manager!
# The PSF is hiring a Developer-in-Residence to support CPython!
# Python 3.10.0a7 is now available for testing
# Python 3.9.4 hotfix is now available
# Python 3.9.3 and 3.8.9 are now available
# More
# Easy Fairish: Basics of Classification and Bias - PyLadies Amsterdam
#  GeoPython 2021
# PyCon US 2021
# Conf42 Python 2021
#  DjangoCon Europe 2021
# Python Software Foundation
# Learn more
# Become a Member
# Donate to the PSF
# ▲ Back to Top
# About
# Applications
# Quotes
# Getting Started
# Help
# Python Brochure
# Downloads
# All releases
# Source code
# Windows
# Mac OS X
# Other Platforms
# License
# Alternative Implementations
# Documentation
# Docs
# Audio/Visual Talks
# Beginner's Guide
# Developer's Guide
# FAQ
# Non-English Docs
# PEP Index
# Python Books
# Python Essays
# Community
# Community Survey
# Diversity
# Mailing Lists
# IRC
# Forums
# PSF Annual Impact Report
# Python Conferences
# Special Interest Groups
# Python Logo
# Python Wiki
# Merchandise
# Community Awards
# Code of Conduct
# Get Involved
# Shared Stories
# Success Stories
# Arts
# Business
# EducationSkip to content
#
# ▼ Close
#
# Python
# PSF
# Docs
# PyPI
# Jobs
# Community
#
# ▲ The Python Network
#
#
# Donate
# ≡ Menu
# A A
# Smaller
# Larger
# Reset
# Socialize
# Facebook
# Twitter
#
# Chat on IRC
# About
# Applications
# Quotes
# Getting Started
# Help
# Python Brochure
# Downloads
# All releases
# Source code
# Windows
# Mac OS X
# Other Platforms
# License
# Alternative Implementations
# Documentation
# Docs
# EngineeringAudio/Visual Talks
# Beginner's Guide
# Developer's Guide
# FAQ
# Non-English Docs
# PEP Index
# Python Books
# Python Essays
# Community
# Community Survey
# Diversity
# Mailing Lists
# IRC
# Forums
# PSF Annual Impact Report
# Python Conferences
# Special Interest Groups
# Python Logo
# Python Wiki
# Merchandise
# Community Awards
# Code of Conduct
# Get Involved
# Shared Stories
# Success Stories
# Arts
# Business
# Education
# Engineering
# Government
# Scientific
# Software Development
# News
# Python News
# PSF Newsletter
# Community News
#
# Government
# Scientific
# Software Development
# News
# Python News
# PSF Newsletter
# PSF NewsCommunity News
# PyCon News
# Events
# Python Events
# User Group Events
# Python Events Archive
# User Group Events Archive
# Submit an Event
# Python’s community is vast
# diverse & aims to grow
# PSF News
# PyCon News
# Events
# Python Events
# User Group Events
# Python Events Archive
# User Group Events Archive
# Submit an Event
# Contributing
# Developer's Guide
# Issue Tracker
# python-dev list
# Core Mentorship
# Report a Security Issue
# ▲ Back to Top
# Help & General Contact
# Python is Open
# Python FAQs
# Attend a Conference
# Diversity Statement
# here
# @alex_gaynor
# Rahul Chaudhary
# pythonweekly.com
# pyslackers.com
# pythondiscord.com
# Freenode IRC
#
# Select an IRC clientDiversity Initiatives
# Submit Website Bug
# Status
# Python Software Foundation
#
# Legal Statementsregister your nickname with Freenode
# ▲ Back to Top
# About
# Applications
# Quotes
# Getting Started
# Help
# Python Brochure
# Downloads
# All releases
# Source code
# Windows
# Mac OS X
# Other Platforms
# License
# Alternative Implementations
# Documentation
# Docs
# Audio/Visual Talks
# Beginner's Guide
# Developer's Guide
#
# FAQ
# Non-English Docs
# Privacy Policy
# Powered by Heroku
# PEP Index
# Python Books
# Python Essays
# Community
# Community Survey
# Diversity
# Mailing Lists
# IRC
# Forums
# PSF Annual Impact Report
# Python Conferences
# Special Interest Groups
# Python Logo
# Python Wiki
# Merchandise
# Community Awards
# Code of Conduct
# Get Involved
# Shared Stories
# Success Stories
# Arts
# Business
# Education
# Engineering
# Government
# Scientific
# Software Development
# News
# Python News
# PSF Newsletter
# Community News
# PSF News
# PyCon News
# Events
# Python Events
# User Group Events
# Python Events Archive
# User Group Events Archive
# Submit an Event
# Contributing
# Developer's Guide
# Issue Tracker
# python-dev list
# Core Mentorship
# Report a Security Issue
# ▲ Back to Top
# Help & General Contact
# Diversity Initiatives
# Submit Website Bug
# Status
# Python Software Foundation
# Legal Statements
# Privacy Policy
# Powered by Heroku
# Skip to content
#
# ▼ Close
#
# Python
# PSF
# Docs
# PyPI
# Jobs
# Community
#
# ▲ The Python Network
#
#
# Donate
# ≡ Menu
# A A
# Smaller
# Larger
# Reset
# Socialize
# Facebook
# Twitter
# Chat on IRC
# About
# Applications
# Quotes
# Getting Started
# Help
# Python Brochure
# Downloads
# All releases
# Source code
# Windows
# Mac OS X
# Other Platforms
# License
# Alternative Implementations
# Documentation
# Docs
# Audio/Visual Talks
# Beginner's Guide
# Developer's Guide
# FAQ
# Non-English Docs
# PEP Index
# Python Books
# Python Essays
# Community
# Community Survey
# Diversity
# Mailing Lists
# IRC
# Forums
# PSF Annual Impact Report
# Python Conferences
# Special Interest Groups
# Python Logo
# Python Wiki
# Merchandise
# Community Awards
# Code of Conduct
# Get Involved
# Shared Stories
# Success Stories
# Arts
# Business
# Education
# Engineering
# Government
# Scientific
# Software Development
# News
# Python News
# PSF Newsletter
# Community News
# PSF News
# PyCon News
# Events
# Python Events
# User Group Events
# Python Events Archive
# User Group Events Archive
# Submit an Event
# >_
#                         Launch Interactive Shell
#
# More about defining functions in Python 3
# More about lists in Python 3
# More about simple math functions in Python 3
# Whet your appetite
# More control flow tools in Python 3
# Learn More
# Start with our Beginner’s Guide
# Python 3.9.4
# docs.python.org
# jobs.python.org
# More
# The PSF is hiring a Python Packaging Project Manager!
# The PSF is hiring a Developer-in-Residence to support CPython!
# Python 3.10.0a7 is now available for testing
# Python 3.9.4 hotfix is now available
# Python 3.9.3 and 3.8.9 are now available
# More
# Easy Fairish: Basics of Classification and Bias - PyLadies Amsterdam
#  GeoPython 2021
# PyCon US 2021
# Conf42 Python 2021
#  DjangoCon Europe 2021
# More
# Python's convenience has made it the most popular language for machine learning and artificial intelligence. Python's flexibility has allowed Anyscale to make ML/AI scalable from laptops to clusters.
# Python provides convenience and flexibility for scalable ML/AI
# More
# Django
# Pyramid
# Bottle
# Tornado
# Flask
# web2py
# tkInter
# PyGObject
# PyQt
# PySide
# Kivy
# wxPython
# SciPy
# Pandas
# IPython
# Buildbot
# Trac
# Roundup
# Ansible
# Salt
# OpenStack
# Python Enhancement Proposals (PEPs)
#  RSS
# Python Software Foundation
# Learn more
# Become a Member
# Donate to the PSF
# ▲ Back to Top
# About
# Applications
# Quotes
# Getting Started
# Help
# Python Brochure
# Downloads
# All releases
# Source code
# Windows
# Mac OS X
# Other Platforms
# License
# Alternative Implementations
# Documentation
# Docs
# Audio/Visual Talks
# Beginner's Guide
# Developer's Guide
# FAQ
# Non-English Docs
# PEP Index
# Python Books
# Python Essays
# Community
# Community Survey
# Diversity
# Mailing Lists
# IRC
# Forums
# PSF Annual Impact Report
# Python Conferences
# Special Interest Groups
# Python Logo
# Python Wiki
# Merchandise
# Community Awards
# Code of Conduct
# Get Involved
# Shared Stories
# Success Stories
# Arts
# Business
# Education
# Engineering
# Government
# Scientific
# Software Development
# News
# Python News
# PSF Newsletter
# Community News
# PSF News
# PyCon News
# Events
# Python Events
# User Group Events
# Python Events Archive
# User Group Events Archive
# Submit an Event
# Contributing
# Developer's Guide
# Issue Tracker
# python-dev list
# Core Mentorship
# Report a Security Issue
# ▲ Back to Top
# Help & General Contact
# Diversity Initiatives
# Submit Website Bug
# Status
# Python Software Foundation
# Legal Statements
# Privacy Policy
# Powered by Heroku
#
#
#
# FrontPage
# FrontPage
# FrontPage
# RecentChanges
# FindPage
# HelpContents
# Comments
# Info
# Attachments
# Login
# WikiEditingGuidelines
# Python
# compared
# various windowing systems
# implementation
# applications written in other languages
# Getting Started
# Events and Community
# Software
# Core Development
# Using and Editing the Wiki
# Beginners Guide
# Documentation
# Beginner Errors
# Python Books
# Asking for Help
# Python Audio Materials
# Languages
# Python Implementations
# documentation category
# Python Conferences
# Local User Groups
# Python Training
# Python Events
# Python Event Calendars
# Participating in the Community
# Python Software Foundation
# Find a job where you can use Python
# Python Projects
# Development Tools
# Applications
# Python Editors
# Useful Modules
# Publishing Python Modules
# The Python Web Site
# Bug Tracker
# Package Index
# Other Resources
# guidelines
# site improvements
# RecentChanges
# RSS feed
# Create new account
# pydotorg-www mailing list
# EditorsGroup
# python.org maintainers
# pydotorg-www mailing list
# password recovery function
# wiki attack description page
# change it
# SteveHolden
# MoinMoin Powered
# Python Powered
# GPL licensed
# Valid HTML 4.01
# Unable to edit the page? See the FrontPage for instructions.
# Skip to main content
#
# Sign In
# Try Now
# Teams
# Individuals
# Features
# Certifications
# Interactive learning
# Live events
# Answers
# What’s New
# O’Reilly for marketers
# AI/ML
# Future of the Firm
# Innovation & Disruption
# Next Architecture
# Next Economy
# Commentary
#
# The Wrong Question
#
# Mike Loukides
# More Commentary
# Deep Dive
#
# The End of Silicon Valley as We Know It?
#
# Tim O’Reilly
# More Deep Dive
# Research
#
# InfoTribes, Reality Brokers
#
# Hugo Bowne-Anderson
# More Research
# Signals
#
# NFTs: Owning Digital Art
#
# Mike Loukides
# More Signals
# About O’Reilly
# Teach/write/train
# Careers
# Community partners
# Affiliate program
# Submit an RFP
# Diversity
# Support
# Contact us
# Newsletters
# Privacy policy
#
# facebook-logo
# linkedin-logo
# youtube-logo
#
#
#
#
# donotsell@oreilly.com
#
#
#
# Terms of service
# Privacy policy
# Editorial independence
# Skip to content
#
# ▼ Close
#
# Python
# PSF
# Docs
# PyPI
# Jobs
# Community
#
# ▲ The Python Network
#
#
# Donate
# ≡ Menu
# A A
# Smaller
# Larger
# Reset
# Socialize
# Facebook
# Twitter
# Chat on IRC
# About
# Applications
# Quotes
# Getting Started
# Help
# Python Brochure
# Downloads
# All releases
# Source code
# Windows
# Mac OS X
# Other Platforms
# License
# Alternative Implementations
# Documentation
# Docs
# Audio/Visual Talks
# Beginner's Guide
# Developer's Guide
# FAQ
# Non-English Docs
# PEP Index
# Python Books
# Python Essays
# Community
# Community Survey
# Diversity
# Mailing Lists
# IRC
# Forums
# PSF Annual Impact Report
# Python Conferences
# Special Interest Groups
# Python Logo
# Python Wiki
# Merchandise
# Community Awards
# Code of Conduct
# Get Involved
# Shared Stories
# Success Stories
# Arts
# Business
# Education
# Engineering
# Government
# Scientific
# Software Development
# News
# Python News
# PSF Newsletter
# Community News
# PSF News
# PyCon News
# Events
# Python Events
# User Group Events
# Python Events Archive
# User Group Events Archive
# Submit an Event
# Download Python 3.9.4
# Download Python 3.9.4
# Download Python 3.9.4
# Download Python 3.9.4
# Windows
# Linux/UNIX
# Mac OS X
# Other
# Prereleases
# Docker images
# For more information visit the Python Developer's Guide
# PEP 596
# PEP 569
# PEP 537
# PEP 494
# PEP 373
# Python 3.9.4
#  Download
# Release Notes
# Python 3.8.9
#  Download
# Release Notes
# Python 3.9.2
#  Download
# Release Notes
# Python 3.8.8
#  Download
# Release Notes
# Python 3.6.13
#  Download
# Release Notes
# Python 3.7.10
# Skip to content Download
#
# ▼ Close
#
# Python
# PSF
# Docs
# PyPI
# Jobs
# Community
#
# ▲ The Python Network
#
#
# Donate
# ≡ Menu
# A A
# Smaller
# Larger
#
# Release Notes
# Python 3.8.7
#  Download
# Release Notes
# Python 3.9.1
#  Download
# Release Notes
# Python 3.9.0
#  Download
# Release Notes
# Python 3.8.6
#  DownloadReset
# Release Notes
# Python 3.5.10
#  Download
# Socialize
# Facebook
# Twitter
# Chat on IRC
# About
# Applications
# Quotes
# Getting Started
# Help
#
# Release Notes
# Python Brochure
# Downloads
# All releases
# Source code
# Windows
# Mac OS XPython 3.7.9
#  Download
#
# Other Platforms
# Release Notes
# Python 3.6.12
# License
# Alternative Implementations
# Documentation
# Docs
# Audio/Visual Talks
# Beginner's Guide
#  DownloadDeveloper's Guide
# FAQ
# Non-English Docs
# PEP Index
# Python Books
# Python Essays
# Community
# Community Survey
#
# Release Notes
# Python 3.8.5
#  Download
# Release Notes
# Python 3.8.4
# Diversity Download
# Release Notes
# Python 3.7.8
#  Download
# Release Notes
# Python 3.6.11
#  Download
# Release Notes
# Python 3.8.3
#  Download
# Release Notes
# Python 2.7.18
#  Download
# Release Notes
#
# Mailing Lists
# IRC
# Forums
# PSF Annual Impact Report
# Python Conferences
# Special Interest Groups
# Python Logo
# Python 3.7.7Python Wiki
# Merchandise
# Community Awards
# Code of Conduct
# Get Involved
# Shared Stories
#
#  Download
# Release Notes
# Python 3.8.2
#  Download
# Success Stories
# Arts
# Release Notes
# Python 3.8.1
# Business
# Education
# Engineering
# Government
# Scientific
#  Download
# Release Notes
# Python 3.7.6
#  Download
# Release Notes
# Python 3.6.10
#  Download
# Release Notes
# Python 3.5.9
#  Download
# Release Notes
# Python 3.5.8
#  DownloadSoftware Development
# Release Notes
# Python 2.7.17
#  Download
# Release Notes
# Python 3.7.5
#  Download
# Release Notes
# Python 3.8.0
#  Download
# Release Notes
# Python 3.7.4
#  Download
# Release Notes
#
# Python 3.6.9
#  DownloadNews
# Release Notes
# Python News
# PSF Newsletter
# Community News
# PSF News
# PyCon News
# Events
# Python Events
# User Group Events
# Python Events Archive
# User Group Events Archive
# Submit an Event
# Python 3.7.3
# Download Python 3.9.4
# Download Python 3.9.4
# Download Python 3.9.4
# Download Python 3.9.4
# Windows
#  Download
# Release Notes
# Python 3.4.10
#  Download
# Release Notes
# Python 3.5.7
#  Download
# Release Notes
#
# Python 2.7.16
#  Download
# Release Notes
# Python 3.7.2
#  Download
# Release Notes
# Python 3.6.8
#  Download
# Release Notes
# Python 3.7.1
#  Download
# Release Notes
# Python 3.6.7
#  Download
# Release Notes
# Python 3.5.6
#  Download
# Release Notes
# Python 3.4.9
#  Download
# Release Notes
# Python 3.7.0
#  Download
# Release Notes
# Python 3.6.6
#  Download
# Linux/UNIX
# Mac OS X
# Release NotesOther
# Prereleases
#
# Python 2.7.15
#  Download
# Release Notes
# Python 3.6.5
# Docker images Download
# Release Notes
# Python 3.4.8
#  Download
# Release Notes
#
# For more information visit the Python Developer's Guide
# PEP 596
# PEP 569
# Python 3.5.5
#  Download
# Release Notes
# Python 3.6.4
#  Download
# Release Notes
# Python 3.6.3
#  Download
# Release Notes
# Python 3.3.7
#  Download
# Release Notes
# Python 2.7.14
#  Download
# Release Notes
# PEP 537Python 3.4.7
#  Download
# Release Notes
# Python 3.5.4
#  Download
# Release Notes
# Python 3.6.2
#
# PEP 494
# PEP 373
#  Download
# Release Notes
# Python 3.6.1
#  Download
# Release Notes
# Python 3.4.6
#  Download
# Release Notes
# Python 3.5.3
#  Download
# Release Notes
# Python 3.6.0
#  Download
# Release Notes
# Python 2.7.13
#  Download
# Release Notes
# Python 3.4.5
#  Download
# Release Notes
# Python 3.9.4Python 3.5.2
#  Download
# Release Notes
# Python 2.7.12
#  Download
# Release Notes
#
#  Download
# Release Notes
# Python 3.8.9Python 3.4.4
#  Download
# Release Notes
# Python 3.5.1
#  Download
# Release Notes
# Python 2.7.11
#  Download
# Release Notes
# Python 3.5.0
#  Download
# Release Notes
# Python 2.7.10
#
#  Download
# Release Notes Download
# Release Notes
# Python 3.9.2
#  Download
# Release Notes
# Python 3.8.8
#  Download
# Release Notes
# Python 3.6.13
#  Download
# Release Notes
# Python 3.7.10
#  Download
# Release Notes
# Python 3.8.7
#  Download
# Release Notes
# Python 3.9.1
#  Download
# Release Notes
# Python 3.9.0
#  Download
# Release Notes
# Python 3.8.6
#  Download
# Release Notes
# Python 3.5.10
#  Download
# Python 3.4.3
#  Download
# Release Notes
# Python 2.7.9
#  Download
# Release Notes
# Python 3.4.2
#  Download
# Release Notes
# Python 3.3.6
#  Download
# Release Notes
# Python 3.2.6
#  Download
# Release Notes
# Python 2.7.8
# Release Notes
# Python 3.7.9
#  Download
# Release Notes
# Python 3.6.12
#  Download
# Release Notes
# Python 3.8.5
#
#  Download
# Release Notes
# Python 3.8.4
#  Download
# Release Notes
# Python 3.7.8
#  Download
# Release Notes
# Python 3.6.11
#  Download
# Release Notes
# Python 3.8.3
#  Download
# Release Notes
# Python 2.7.18
#  Download
# Release Notes
# Python 3.7.7
#  Download
#  DownloadRelease Notes
# Python 2.7.7
#  Download
# Release Notes
#
# Release Notes
# Python 3.8.2
#  Download
# Release Notes
# Python 3.8.1
#  Download
# Release Notes
# Python 3.7.6
#  Download
# Release Notes
# Python 3.6.10
#  Download
# Release Notes
# Python 3.5.9
#  DownloadPython 3.4.1
#  Download
# Release Notes
# Python 3.4.0
#  Download
# Release Notes
# Python 3.3.5
#
# Release Notes
# Python 3.5.8
#  Download
# Release Notes
#  Download
# Release Notes
# Python 3.3.4
#  Download
# Release Notes
# Python 3.3.3
#  Download
# Release Notes
# Python 2.7.6Python 2.7.17
#  Download
# Release Notes
# Python 3.7.5
#  Download
# Release Notes
# Python 3.8.0
#  Download
# Release Notes
# Python 3.7.4
#  Download
# Release Notes
#
#  Download
# Release Notes
# Python 2.6.9
#  Download
# Release Notes
# Python 3.2.5
#  Download
# Release Notes
# Python 3.3.2
#  Download
# Release Notes
# Python 2.7.5
# Python 3.6.9
#  Download
#  DownloadRelease Notes
# Python 3.7.3
#  Download
# Release Notes
# Python 3.4.10
#  Download
# Release Notes
# Python 3.5.7
#  Download
# Release Notes
# Python 2.7.16
#  Download
# Release Notes
# Python 3.7.2
#  Download
# Release Notes
# Python 3.6.8
#  Download
# Release Notes
# Python 3.7.1
#  Download
#
# Release Notes
# Python 3.6.7
#  Download
# Release Notes
# Python 3.5.6
#  Download
# Release Notes
# Python 3.4.9
#  Download
# Release Notes
# Python 3.7.0
#  Download
# Release Notes
# Python 3.6.6
#  Download
# Release Notes
# Python 2.7.15
#  Download
# Release Notes
# Python 3.6.5
#  Download
# Release Notes
# Python 3.4.8
#  Download
# Release Notes
# Python 3.5.5
#  Download
# Release Notes
# Python 3.6.4
#  Download
# Release Notes
# Python 3.6.3
#  Download
# Release Notes
# Python 3.3.7
# Release Notes
# Python 2.7.4
#  Download
# Release Notes
# Python 3.2.4
#  Download
# Release Notes
# Python 3.3.1
#  Download
# Release Notes
# Python 3.3.0
#  Download
# Release Notes
# Python 3.2.3
#  Download Download
# Release Notes
# Release Notes
# Python 2.7.14
#  Download
# Release Notes
# Python 3.4.7
#  Download
# Release Notes
# Python 3.5.4
#  Download
# Release Notes
# Python 3.6.2
#
# Python 2.6.8
#  Download
# Release Notes
# Python 3.6.1
#  Download
# Release Notes
# Python 3.4.6 Download
#  Download
# Release Notes
# Python 3.5.3
#  Download
# Release Notes
# Python 3.6.0
#
# Release Notes
# Python 2.7.3
#  Download
# Release Notes
# Python 3.1.5
#  Download
# Release Notes
# Python 2.7.13
#  Download
# Release Notes
# Python 3.4.5
#  Download
# Release Notes
# Python 3.5.2
#  Download Download
# Release Notes
# Python 3.2.2
#  Download
# Release Notes
# Python 3.2.1
#  Download
# Release Notes
# Release Notes
# Python 2.7.12
#  Download
# Release Notes
# Python 3.4.4
#  Download
# Release Notes
# Python 3.5.1
#
# Python 2.7.2
#  Download
# Release Notes
# Python 3.1.4
#  Download
# Release Notes
# Python 2.6.7
#  Download
# Release Notes Download
# Python 2.5.6
#  Download
# Release Notes
# Python 3.2.0
#  Download
# Release Notes
# Python 2.7.1
#  Download
# Release Notes
# Python 3.1.3
#  Download
# Release Notes
# Python 2.6.6
#  Download
# Release Notes
# Python 2.7.0
#  Download
# Release Notes
# Python 3.1.2
#  Download
# Release Notes
# Python 2.6.5
#  Download
# Release Notes
# Python 2.5.5
#  Download
# Release Notes
# Python 2.6.4
#  Download
# Release Notes
# Python 2.6.3
#  Download
# Release Notes
# Python 3.1.1
#  Download
# Release Notes
# Python 3.1.0
#  Download
# Release Notes
# Release Notes
# Python 2.7.11
#  Download
# Release Notes
# Python 3.5.0
#
#  Download
# Release Notes
# Python 2.7.10Python 2.6.2
#  Download
# Release Notes
# Python 3.0.1
#  Download
# Release Notes
#  Download
# Release Notes
# Python 3.4.3
#  Download
#
# Python 2.5.4
#  Download
# Release Notes
# Python 2.5.3
#  Download
# Release Notes
# Python 2.4.6
#  Download
# Release Notes
# Python 2.6.1
#  Download
# Release Notes
# Release Notes
# Python 3.0.0Python 2.7.9
#  Download
# Release Notes
# Python 3.4.2
#  Download
# Release Notes
# Python 3.3.6
#  Download
# Release Notes
# Python 3.2.6
#  Download
# Release Notes
# Python 2.7.8
#  Download
# Release Notes
# Python 2.7.7
#  Download
# Release Notes
# Python 3.4.1
#  Download
# Release Notes
# Python 3.4.0
#  Download
# Release Notes
# Python 3.3.5
#  Download
# Release Notes
# Python 3.3.4
#  Download
# Release Notes
# Python 3.3.3
#  Download
# Release Notes
# Python 2.7.6
#  Download
#
# Release Notes Download
# Release Notes
# Python 2.6.0
#  Download
# Release Notes
# Python 2.4.5
#  Download
# Release Notes
#
# Python 2.3.7Python 2.6.9
#  Download
# Release Notes
# Python 3.2.5
#  Download
# Release Notes
# Python 3.3.2
#  Download
# Release Notes
#
# Python 2.7.5
#  Download
# Release Notes
# Python 2.7.4
#  Download
# Release Notes
# Python 3.2.4
#  Download Download
# Release Notes
# Python 3.3.1
#  Download
# Release Notes
# Python 3.3.0
#  Download
# Release Notes
#
# Release Notes
# Python 2.5.2
#  Download
# Release NotesPython 3.2.3
#
# Python 2.5.1
#  Download
# Release Notes
# Python 2.3.6
#  Download
# Release Notes
# Python 2.4.4
#  Download
# Release Notes
# Python 2.5.0
#  Download
# Release Notes
# Python 2.4.3
#  Download Download
#
# Release Notes
# Python 2.4.2
#  Download
# Release Notes
# Python 2.4.1
#  Download
# Release Notes
# Python 2.3.5
#  Download
# Release Notes
# Python 2.4.0
# Release Notes
# Python 2.6.8
#  Download
# Release Notes
# Python 2.7.3 Download
#  Download
# Release Notes
# Python 3.1.5
#  Download
# Release Notes
# Python 2.3.4
#
#  Download
# Release Notes
# Python 2.3.3
#  Download
# Release Notes
# Python 2.3.2
#  Download
# Release NotesRelease Notes
# Python 2.3.1
#  Download
# Release Notes
# Python 2.3.0
#  Download
# Release Notes
# Python 2.2.3
# Python 3.2.2
#  Download
# Release Notes
#  Download
# Python 3.2.1
#  Download
# Release Notes
# Python 2.2.2
#  Download
# Release Notes
# Python 2.2.1
#  Download
# Release Notes
# Python 2.1.3
#
# Release Notes
# Python 2.7.2
#  Download
# Release Notes
#  DownloadPython 3.1.4
#  Download
# Release Notes
# Python 2.6.7
#
# Release Notes
# Python 2.2.0
#  Download
# Release Notes
# Python 2.0.1
#  Download
# Release Notes Download
# Release Notes
# Python 2.5.6
#  Download
# Release Notes
# Python 3.2.0
#  Download
# Release Notes
# Python 2.7.1
# View older releases
#  Download
# Release Notes
# Python 3.1.3
#  Download
# Open Source
# Release Notes
# Python 2.6.6
#  Download
# Release Notes
# Python 2.7.0
#
#  Download
# Release Notes
# Python 3.1.2
#  Download
# Release NotesRead more
# Python 2.6.5
#  Download
# Python 3
# Python 2
# Read more
# Read more
# Read more
# Python 3.9 Release Schedule
# Python 3.8 Release Schedule
# Python 3.7 Release Schedule
# Python 3.6 Release Schedule
# Python 3.5 Release Schedule
# Python 2.7 Release Schedule
# Windows (and DOS)
# Macintosh
# Other platforms
# Source
# Python Developer's Guide
# Python Issue Tracker
# Pablo Galindo Salgado (3.10.x and 3.11.x source files and tags)
# 64E628F8D684696D
# Steve Dower (Windows binaries)
# FC62 4643 4870 34E5
# Łukasz Langa (3.8.x and 3.9.x source files and tags)
# B269 95E3 1025 0568
# Ned Deily (macOS binaries, 3.7.x / 3.6.x source files and tags)
# 2D34 7EA6 AA65 421D
# FB99 2128 6F5E 1540
# Benjamin Peterson (2.7.z source files and tags)
# 04C3 67C2 18AD D4FF
# 6AF0 53F0 7D9D C8D2
# Barry Warsaw
# 126E B563 A74B 06BF
# D986 6941 EA5B BD71, and ED9D77D5
# Release Notes
# Python 2.5.5
#  Download
# Release Notes
# Python 2.6.4
#  Download
# Release Notes
# Python 2.6.3
#  Download
# Release Notes
# Python 3.1.1
#  Download
# Release Notes
# Python 3.1.0
#  Download
# Release Notes
# Python 2.6.2
#
# keybase.io
# GnuPG
# Package Index
# view
# download
# Documentation
# tools for unpacking archive files
# source
# collection of Emacs packages
# Python Developer's Guide
# ▲ Back to Top
# About
# Applications
# Quotes
# Getting Started
# Help Download
# Python Brochure
# Downloads
# Release Notes
# Python 3.0.1
#  Download
# Release Notes
# Python 2.5.4
#  Download
# Release Notes
# Python 2.5.3
#  Download
# Release Notes
# Python 2.4.6
#  Download
# Release Notes
#
# Python 2.6.1All releases
# Source code
# Windows
# Mac OS X
# Other Platforms
# License
# Alternative Implementations
# Documentation
# Docs
# Audio/Visual Talks
# Beginner's Guide
# Developer's Guide
# FAQ
#
# Non-English Docs
# PEP Index
# Python Books
# Python Essays
# Community
# Community Survey Download
# Diversity
# Mailing Lists
# IRC
# Forums
# PSF Annual Impact Report
# Python Conferences
# Special Interest Groups
# Python Logo
# Python Wiki
# Merchandise
#
# Community Awards
# Code of Conduct
# Get Involved
# Shared Stories
# Success Stories
# Arts
# Business
# Education
# Engineering
# Government
# Scientific
# Software Development
# News
# Python News
# Release Notes
# Python 3.0.0
#  Download
# Release NotesPSF Newsletter
# Python 2.6.0
#  Download
#
# Release Notes
# Python 2.4.5
#  DownloadCommunity News
# PSF News
#
# Release Notes
# Python 2.3.7
#  Download
# Release Notes
# Python 2.5.2
#  Download
# Release Notes
# Python 2.5.1
# PyCon News Download
# Release Notes
# Python 2.3.6
#  Download
# Release Notes
# Python 2.4.4
#  Download
# Release Notes
# Python 2.5.0
#  Download
# Release Notes
# Python 2.4.3
#  Download
#
# Release Notes
# Python 2.4.2
#  Download
# Release Notes
# Python 2.4.1
#  Download
# Release Notes
# Python 2.3.5
#  Download
# Release Notes
# Python 2.4.0
#  Download
# Release Notes
# Python 2.3.4
#  Download
# Release NotesEvents
# Python 2.3.3
#  Download
# Release Notes
# Python 2.3.2
#  Download
#
# Release Notes
# Python 2.3.1
#  Download
# Release Notes
# Python Events
# User Group Events
# Python Events Archive
# User Group Events Archive
# Python 2.3.0Submit an Event
# Contributing
# Developer's Guide
# Issue Tracker
# python-dev list
# Core Mentorship
#  Download
# Release Notes
# Python 2.2.3
#  Download
# Release Notes
# Python 2.2.2
#  Download
# Release Notes
# Python 2.2.1
#  Download
# Report a Security Issue
# ▲ Back to Top
# Help & General Contact
# Diversity Initiatives
# Submit Website Bug
# Status
# Python Software Foundation
# Legal Statements
# Privacy Policy
# Powered by Heroku
#
# Release Notes
# Python 2.1.3
#  Download
# Release Notes
# Python 2.2.0
#  Download
# Release Notes
# Python 2.0.1
#  Download
# Release Notes
# View older releases
# Open Source
# Read more
# Python 3
# Python 2
# Read more
# Read more
# Read more
# Python 3.9 Release Schedule
# Python 3.8 Release Schedule
# Python 3.7 Release Schedule
# Python 3.6 Release Schedule
# Python 3.5 Release Schedule
# Python 2.7 Release Schedule
# Windows (and DOS)
# Macintosh
# Other platforms
# Source
# Python Developer's Guide
# Python Issue Tracker
# Pablo Galindo Salgado (3.10.x and 3.11.x source files and tags)
# 64E628F8D684696D
# Steve Dower (Windows binaries)
# FC62 4643 4870 34E5
# Łukasz Langa (3.8.x and 3.9.x source files and tags)
# B269 95E3 1025 0568
# Ned Deily (macOS binaries, 3.7.x / 3.6.x source files and tags)
# 2D34 7EA6 AA65 421D
# FB99 2128 6F5E 1540
# Benjamin Peterson (2.7.z source files and tags)
# 04C3 67C2 18AD D4FF
# 6AF0 53F0 7D9D C8D2
# Barry Warsaw
# 126E B563 A74B 06BF
# D986 6941 EA5B BD71, and ED9D77D5
# keybase.io
# GnuPG
# Package Index
# view
# download
# Documentation
# tools for unpacking archive files
# source
# collection of Emacs packages
# Python Developer's Guide
# ▲ Back to Top
# About
# Applications
# Quotes
# Getting Started
# Help
# Python Brochure
# Downloads
# All releases
# Source code
# Windows
# Mac OS X
# Other Platforms
# License
# Alternative Implementations
# Documentation
# Docs
# Audio/Visual Talks
# Beginner's Guide
# Developer's Guide
# FAQ
# Non-English Docs
# PEP Index
# Python Books
# Python Essays
# Community
# Community Survey
# Diversity
# Mailing Lists
# IRC
# Forums
# PSF Annual Impact Report
# Python Conferences
# Special Interest Groups
# Python Logo
# Python Wiki
# Merchandise
# Community Awards
# Code of Conduct
# Get Involved
# Shared Stories
# Success Stories
# Arts
# Business
# Education
# Engineering
# Government
# Scientific
# Software Development
# News
# Python News
# PSF Newsletter
# Community News
# PSF News
# PyCon News
# Events
# Python Events
# User Group Events
# Python Events Archive
# User Group Events Archive
# Submit an Event
# Contributing
# Developer's Guide
# Issue Tracker
# python-dev list
# Core Mentorship
# Report a Security Issue
# ▲ Back to Top
# Help & General Contact
# Diversity Initiatives
# Submit Website Bug
# Status
# Python Software Foundation
# Legal Statements
# Privacy Policy
# Powered by Heroku
